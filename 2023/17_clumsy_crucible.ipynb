# %% [markdown]
# # December 17, 2023
#
# https://adventofcode.com/2023/day/17

# %%
from queue import PriorityQueue
from collections import defaultdict

# %%
tmp = defaultdict( list )

# %%
test = f'''2413432311323
3215453535623
3255245654254
3446585845452
4546657867536
1438598798454
4457876987766
3637877979653
4654967986887
4564679986453
1224686865563
2546548887735
4322674655533'''

test = test.split("\n")
test = [ [int(y) for y in line] for line in test]

# %%
fn = "data/17.txt"
with open(fn, "r") as file:
    text = file.readlines()

puzz = [x.strip() for x in text]
puzz = [ [int(y) for y in line] for line in puzz ]

# %% [markdown]
# ### Part 1

# %%
# row and col refer to map[row][col] in the text
# hist is up to three letters all the same, such as "uuu" or "rr"
def encode( row, col, hist ):
    return str(row) + ":" + str(col) + ":" + hist

def split_label( label ):
    # split out hist, but leave row:col together
    row, col, hist = label.split(":")
    return row + ":" + col, hist

def decode( label ):
    row, col, hist = label.split(":")
    return int(row), int(col), hist

def update_hist( hist, dir ):
    # update history after moving in dir 
    # basically appending it if we haven't changed direction, else overwriting it
    # returns None if it makes the hist too long in one direction or we try to backtrack

    # PART 1:
    #min_straight=0
    #max_straight=3

    # PART 2:
    min_straight=4
    max_straight=10

    # X is for initial case where we haven't moved at all yet
    no_backsies = {'u':'d', 'd':'u', 'l':'r', 'r':'l', "X":"X"}

    if dir == no_backsies[hist[-1]]:
        return None
    
    if dir == hist[0]:
        # check if we can take another step this direction
        if len(hist) == max_straight:
            return None
        return hist + dir
    else:
        # check if we can turn yet
        if (len(hist) < min_straight) and hist[0] != "X":
            return None
        return dir
    
def find_neighbors( row, col, hist, mapa ):
    nbrs = list()
    if row > 0:
        hist2 = update_hist(hist, "u")
        if hist2 is not None:
            nbrs.append( encode(row-1, col, hist2) )

    if row < len(mapa)-1:
        hist2 = update_hist(hist, "d")
        if hist2 is not None:
            nbrs.append( encode(row+1, col, hist2) )

    if col > 0:
        hist2 = update_hist(hist, "l")
        if hist2 is not None:
            nbrs.append( encode(row, col-1, hist2) )

    if col < len(mapa[0])-1:
        hist2 = update_hist(hist, "r")
        if hist2 is not None:
            nbrs.append( encode(row, col+1, hist2) )

    return nbrs

def approx( row, col, goal, min_cost = 1 ):
    #r,c, _ = decode(nbr)
    return ((goal[0] - row) + (goal[1]-col)) * min_cost
    
def assemble_path( cur, came_from ):
    path = [cur]
    while came_from[ path[0] ] is not None:
        path.insert(0, came_from[path[0]] )

    return path

def astar( mapa, start=[0,0], goal=None ):
    if goal is None:
        goal = [len(mapa)-1, len(mapa[0])-1]

    frontier = PriorityQueue()
    explored = dict() # keyed by state, valued by cost from start to that state
    came_from = dict()

    # initial status
    start_lab = encode(0,0, "X")
    frontier.put( (approx(start[0], start[1], goal), start_lab ) )
    explored[start_lab] = 0
    came_from[start_lab] = None

    while not frontier.empty():
        cur = frontier.get()[1] # 0 is the priority
        row, col, hist = decode(cur)
        if [row, col] == goal:
            break

        cost_so_far = explored[cur]
        nbrs = find_neighbors( row, col, hist, mapa )
       # print(cur)
        #print(nbrs)
        for n in nbrs:
            r,c, hist = decode( n )
            new_cost = cost_so_far + mapa[r][c]

            if n not in explored or new_cost < explored[n]:
                explored[n] = new_cost
                priority = new_cost + approx( r, c, goal )
                frontier.put( (priority, n) )
                came_from[n] = cur

    if [row, col] == goal:
        print("Yes!")
        path = assemble_path( cur, came_from )
        return explored[cur], path, came_from

# %%
cost, pth, came_from = astar( test )
# Out:
# Yes!

# %%
cost, pth
# Out:
# (94,
#  ['0:0:X',
#   '0:1:r',
#   '0:2:rr',
#   '0:3:rrr',
#   '0:4:rrrr',
#   '0:5:rrrrr',
#   '0:6:rrrrrr',
#   '0:7:rrrrrrr',
#   '0:8:rrrrrrrr',
#   '1:8:d',
#   '2:8:dd',
#   '3:8:ddd',
#   '4:8:dddd',
#   '4:9:r',
#   '4:10:rr',
#   '4:11:rrr',
#   '4:12:rrrr',
#   '5:12:d',
#   '6:12:dd',
#   '7:12:ddd',
#   '8:12:dddd',
#   '9:12:ddddd',
#   '10:12:dddddd',
#   '11:12:ddddddd',
#   '12:12:dddddddd'])

# %%
cost, pth, came_from = astar( puzz )
# Out:
# Yes!

# %%
cost
# Out:
# 797

# %% [markdown]
# ### Part 2

# %%
cost, pth, came_from = astar( test )
# Out:
# 0:0:X
# ['1:0:d', '0:1:r']
# 1:0:d
# ['2:0:dd']
# 0:1:r
# ['0:2:rr']
# 0:2:rr
# ['0:3:rrr']
# 2:0:dd
# ['3:0:ddd']
# 0:3:rrr
# ['0:4:rrrr']
# 3:0:ddd
# ['4:0:dddd']
# 0:4:rrrr
# ['1:4:d', '0:5:rrrrr']
# 4:0:dddd
# ['5:0:ddddd', '4:1:r']
# 5:0:ddddd
# ['6:0:dddddd', '5:1:r']
# 0:5:rrrrr
# ['1:5:d', '0:6:rrrrrr']
# 0:6:rrrrrr
# ['1:6:d', '0:7:rrrrrrr']
# 1:4:d
# ['2:4:dd']
# 2:4:dd
# ['3:4:ddd']
# 5:1:r
# ['5:2:rr']
# 6:0:dddddd
# ['7:0:ddddddd', '6:1:r']
# 0:7:rrrrrrr
# ['1:7:d', '0:8:rrrrrrrr']
# 0:8:rrrrrrrr
# ['1:8:d', '0:9:rrrrrrrrr']
# 0:9:rrrrrrrrr
# ['1:9:d', '0:10:rrrrrrrrrr']
# 1:6:d
# ['2:6:dd']
# 4:1:r
# ['4:2:rr']
# 1:5:d
# ['2:5:dd']
# 5:2:rr
# ['5:3:rrr']
# 7:0:ddddddd
# ['8:0:dddddddd', '7:1:r']
# 0:10:rrrrrrrrrr
# ['1:10:d']
# 1:8:d
# ['2:8:dd']
# 6:1:r
# ['6:2:rr']
# 3:4:ddd
# ['4:4:dddd']
# 4:2:rr
# ['4:3:rrr']
# 1:7:d
# ['2:7:dd']
# 1:9:d
# ['2:9:dd']
# 2:5:dd
# ['3:5:ddd']
# 2:6:dd
# ['3:6:ddd']
# 8:0:dddddddd
# ['9:0:ddddddddd', '8:1:r']
# 2:8:dd
# ['3:8:ddd']
# 6:2:rr
# ['6:3:rrr']
# 7:1:r
# ['7:2:rr']
# 1:10:d
# ['2:10:dd']
# 2:9:dd
# ['3:9:ddd']
# 9:0:ddddddddd
# ['10:0:dddddddddd', '9:1:r']
# 10:0:dddddddddd
# ['10:1:r']
# 10:1:r
# ['10:2:rr']
# 2:10:dd
# ['3:10:ddd']
# 3:6:ddd
# ['4:6:dddd']
# 4:3:rrr
# ['4:4:rrrr']
# 4:4:dddd
# ['5:4:ddddd', '4:3:l', '4:5:r']
# 5:3:rrr
# ['5:4:rrrr']
# 7:2:rr
# ['7:3:rrr']
# 10:2:rr
# ['10:3:rrr']
# 2:7:dd
# ['3:7:ddd']
# 3:8:ddd
# ['4:8:dddd']
# 8:1:r
# ['8:2:rr']
# 3:10:ddd
# ['4:10:dddd']
# 3:5:ddd
# ['4:5:dddd']
# 3:9:ddd
# ['4:9:dddd']
# 9:1:r
# ['9:2:rr']
# 10:3:rrr
# ['10:4:rrrr']
# 4:5:r
# ['4:6:rr']
# 5:4:ddddd
# ['6:4:dddddd', '5:3:l', '5:5:r']
# 5:4:rrrr
# ['4:4:u', '6:4:d', '5:5:rrrrr']
# 6:3:rrr
# ['6:4:rrrr']
# 4:4:rrrr
# ['3:4:u', '5:4:d', '4:5:rrrrr']
# 8:2:rr
# ['8:3:rrr']
# 4:6:dddd
# ['5:6:ddddd', '4:5:l', '4:7:r']
# 4:8:dddd
# ['5:8:ddddd', '4:7:l', '4:9:r']
# 7:3:rrr
# ['7:4:rrrr']
# 4:10:dddd
# ['5:10:ddddd', '4:9:l', '4:11:r']
# 4:3:l
# ['4:2:ll']
# 4:5:dddd
# ['5:5:ddddd', '4:4:l', '4:6:r']
# 3:7:ddd
# ['4:7:dddd']
# 8:3:rrr
# ['8:4:rrrr']
# 9:2:rr
# ['9:3:rrr']
# 10:4:rrrr
# ['9:4:u', '11:4:d', '10:5:rrrrr']
# 4:11:r
# ['4:12:rr']
# 4:5:rrrrr
# ['3:5:u', '5:5:d', '4:6:rrrrrr']
# 4:9:dddd
# ['5:9:ddddd', '4:8:l', '4:10:r']
# 5:4:d
# ['6:4:dd']
# 4:6:rr
# ['4:7:rrr']
# 5:10:ddddd
# ['6:10:dddddd', '5:9:l', '5:11:r']
# 3:4:u
# ['2:4:uu']
# 4:4:u
# ['3:4:uu']
# 6:4:d
# ['7:4:dd']
# 6:4:dddddd
# ['7:4:ddddddd', '6:3:l', '6:5:r']
# 6:4:rrrr
# ['5:4:u', '7:4:d', '6:5:rrrrr']
# 9:3:rrr
# ['9:4:rrrr']
# 4:2:ll
# ['4:1:lll']
# 4:5:l
# ['4:4:ll']
# 4:9:r
# ['4:10:rr']
# 5:5:r
# ['5:6:rr']
# 5:5:rrrrr
# ['4:5:u', '6:5:d', '5:6:rrrrrr']
# 11:4:d
# ['12:4:dd']
# 4:10:r
# ['4:11:rr']
# 4:6:r
# ['4:7:rr']
# 4:7:r
# ['4:8:rr']
# 5:3:l
# ['5:2:ll']
# 5:6:ddddd
# ['6:6:dddddd', '5:5:l', '5:7:r']
# 7:4:rrrr
# ['6:4:u', '8:4:d', '7:5:rrrrr']
# 2:4:uu
# ['1:4:uuu']
# 4:12:rr
# []
# 4:4:l
# ['4:3:ll']
# 5:11:r
# ['5:12:rr']
# 5:8:ddddd
# ['6:8:dddddd', '5:7:l', '5:9:r']
# 4:11:rr
# ['4:12:rrr']
# 4:6:rrrrrr
# ['3:6:u', '5:6:d', '4:7:rrrrrrr']
# 4:7:dddd
# ['5:7:ddddd', '4:6:l', '4:8:r']
# 4:7:l
# ['4:6:ll']
# 4:9:l
# ['4:8:ll']
# 5:5:ddddd
# ['6:5:dddddd', '5:4:l', '5:6:r']
# 10:5:rrrrr
# ['9:5:u', '11:5:d', '10:6:rrrrrr']
# 4:10:rr
# ['4:11:rrr']
# 4:8:l
# ['4:7:ll']
# 5:9:ddddd
# ['6:9:dddddd', '5:8:l', '5:10:r']
# 6:10:dddddd
# ['7:10:ddddddd', '6:9:l', '6:11:r']
# 6:4:dd
# ['7:4:ddd']
# 8:4:rrrr
# ['7:4:u', '9:4:d', '8:5:rrrrr']
# 9:4:rrrr
# ['8:4:u', '10:4:d', '9:5:rrrrr']
# 9:4:u
# ['8:4:uu']
# 3:4:uu
# ['2:4:uuu']
# 4:7:rrr
# ['4:8:rrrr']
# 5:12:rr
# []
# 5:2:ll
# ['5:1:lll']
# 5:4:u
# ['4:4:uu']
# 5:5:d
# ['6:5:dd']
# 6:5:r
# ['6:6:rr']
# 6:5:rrrrr
# ['5:5:u', '7:5:d', '6:6:rrrrrr']
# 12:4:dd
# []
# 3:5:u
# ['2:5:uu']
# 4:11:rrr
# ['4:12:rrrr']
# 4:1:lll
# ['4:0:llll']
# 4:5:u
# ['3:5:uu']
# 4:8:rr
# ['4:9:rrr']
# 6:5:d
# ['7:5:dd']
# 6:6:dddddd
# ['7:6:ddddddd', '6:5:l', '6:7:r']
# 7:4:d
# ['8:4:dd']
# 7:4:dd
# ['8:4:ddd']
# 7:4:ddddddd
# ['8:4:dddddddd', '7:3:l', '7:5:r']
# 11:5:d
# ['12:5:dd']
# 1:4:uuu
# ['0:4:uuuu']
# 4:4:ll
# ['4:3:lll']
# 5:10:r
# ['5:11:rr']
# 5:6:rr
# ['5:7:rrr']
# 5:6:rrrrrr
# ['4:6:u', '6:6:d', '5:7:rrrrrrr']
# 5:7:r
# ['5:8:rr']
# 5:9:l
# ['5:8:ll']
# 6:3:l
# ['6:2:ll']
# 7:5:rrrrr
# ['6:5:u', '8:5:d', '7:6:rrrrrr']
# 2:4:uuu
# ['1:4:uuuu']
# 4:12:rrr
# []
# 4:7:rr
# ['4:8:rrr']
# 4:8:r
# ['4:9:rr']
# 10:4:d
# ['11:4:dd']
# 10:6:rrrrrr
# ['9:6:u', '11:6:d', '10:7:rrrrrrr']
# 3:6:u
# ['2:6:uu']
# 4:3:ll
# ['4:2:lll']
# 5:4:l
# ['5:3:ll']
# 5:7:ddddd
# ['6:7:dddddd', '5:6:l', '5:8:r']
# 5:9:r
# ['5:10:rr']
# 6:11:r
# ['6:12:rr']
# 6:5:dddddd
# ['7:5:ddddddd', '6:4:l', '6:6:r']
# 6:8:dddddd
# ['7:8:ddddddd', '6:7:l', '6:9:r']
# 7:10:ddddddd
# ['8:10:dddddddd', '7:9:l', '7:11:r']
# 8:4:d
# ['9:4:dd']
# 8:5:rrrrr
# ['7:5:u', '9:5:d', '8:6:rrrrrr']
# 9:4:d
# ['10:4:dd']
# 4:7:rrrrrrr
# ['3:7:u', '5:7:d', '4:8:rrrrrrrr']
# 4:8:ll
# ['4:7:lll']
# 4:8:rrrr
# ['3:8:u', '5:8:d', '4:9:rrrrr']
# 5:1:lll
# ['5:0:llll']
# 5:6:d
# ['6:6:dd']
# 5:6:r
# ['5:7:rr']
# 5:7:l
# ['5:6:ll']
# 6:4:u
# ['5:4:uu']
# 6:6:rr
# ['6:7:rrr']
# 6:6:rrrrrr
# ['5:6:u', '7:6:d', '6:7:rrrrrrr']
# 6:9:dddddd
# ['7:9:ddddddd', '6:8:l', '6:10:r']
# 9:5:rrrrr
# ['8:5:u', '10:5:d', '9:6:rrrrrr']
# 2:5:uu
# ['1:5:uuu']
# 4:0:llll
# ['3:0:u', '5:0:d']
# 4:12:rrrr
# ['3:12:u', '5:12:d']
# 4:6:l
# ['4:5:ll']
# 4:6:ll
# ['4:5:lll']
# 5:0:d
# ['6:0:dd']
# 5:11:rr
# ['5:12:rrr']
# 5:5:l
# ['5:4:ll']
# 6:5:dd
# ['7:5:ddd']
# 7:4:ddd
# ['8:4:dddd']
# 7:5:d
# ['8:5:dd']
# 0:4:uuuu
# ['0:3:l', '0:5:r']
# 4:4:uu
# ['3:4:uuu']
# 4:9:rrr
# ['4:10:rrrr']
# 5:0:llll
# ['4:0:u', '6:0:d']
# 5:10:rr
# ['5:11:rrr']
# 6:6:d
# ['7:6:dd']
# 6:9:l
# ['6:8:ll']
# 7:5:dd
# ['8:5:ddd']
# 7:5:r
# ['7:6:rr']
# 7:6:ddddddd
# ['8:6:dddddddd', '7:5:l', '7:7:r']
# 8:5:d
# ['9:5:dd']
# 9:5:u
# ['8:5:uu']
# 11:4:dd
# ['12:4:ddd']
# 12:5:dd
# []
# 1:4:uuuu
# ['0:4:uuuuu', '1:3:l', '1:5:r']
# 4:7:ll
# ['4:6:lll']
# 4:8:rrr
# ['4:9:rrrr']
# 5:7:rrr
# ['5:8:rrrr']
# 5:7:rrrrrrr
# ['4:7:u', '6:7:d', '5:8:rrrrrrrr']
# 6:2:ll
# ['6:1:lll']
# 7:11:r
# ['7:12:rr']
# 7:4:u
# ['6:4:uu']
# 7:6:rrrrrr
# ['6:6:u', '8:6:d', '7:7:rrrrrrr']
# 0:5:r
# ['0:6:rr']
# 10:4:dd
# ['11:4:ddd']
# 3:12:u
# ['2:12:uu']
# 4:2:lll
# ['4:1:llll']
# 4:3:lll
# ['4:2:llll']
# 4:9:rr
# ['4:10:rrr']
# 5:12:d
# ['6:12:dd']
# 5:12:rrr
# []
# 5:8:l
# ['5:7:ll']
# 6:0:dd
# ['7:0:ddd']
# 6:12:rr
# []
# 6:5:l
# ['6:4:ll']
# 6:6:r
# ['6:7:rr']
# 6:7:r
# ['6:8:rr']
# 7:3:l
# ['7:2:ll']
# 8:4:dd
# ['9:4:ddd']
# 8:4:ddd
# ['9:4:dddd']
# 8:4:dddddddd
# ['9:4:ddddddddd', '8:3:l', '8:5:r']
# 8:4:u
# ['7:4:uu']
# 8:4:uu
# ['7:4:uuu']
# 9:4:dd
# ['10:4:ddd']
# 0:6:rr
# ['0:7:rrr']
# 2:6:uu
# ['1:6:uuu']
# 3:0:u
# ['2:0:uu']
# 3:5:uu
# ['2:5:uuu']
# 3:8:u
# ['2:8:uu']
# 4:6:u
# ['3:6:uu']
# 4:8:rrrrrrrr
# ['3:8:u', '5:8:d', '4:9:rrrrrrrrr']
# 5:5:u
# ['4:5:uu']
# 5:8:rr
# ['5:9:rrr']
# 6:0:d
# ['7:0:dd']
# 6:5:u
# ['5:5:uu']
# 6:6:dd
# ['7:6:ddd']
# 6:9:r
# ['6:10:rr']
# 7:12:rr
# []
# 7:5:ddddddd
# ['8:5:dddddddd', '7:4:l', '7:6:r']
# 7:8:ddddddd
# ['8:8:dddddddd', '7:7:l', '7:9:r']
# 8:6:rrrrrr
# ['7:6:u', '9:6:d', '8:7:rrrrrrr']
# 9:5:d
# ['10:5:dd']
# 0:3:l
# ['0:2:ll']
# 10:7:rrrrrrr
# ['9:7:u', '11:7:d', '10:8:rrrrrrrr']
# 11:6:d
# ['12:6:dd']
# 4:10:rrrr
# ['3:10:u', '5:10:d', '4:11:rrrrr']
# 4:9:rrrrr
# ['3:9:u', '5:9:d', '4:10:rrrrrr']
# 5:11:rrr
# ['5:12:rrrr']
# 5:4:uu
# ['4:4:uuu']
# 5:7:d
# ['6:7:dd']
# 5:7:rr
# ['5:8:rrr']
# 6:10:r
# ['6:11:rr']
# 7:0:ddd
# ['8:0:dddd']
# 7:6:d
# ['8:6:dd']
# 8:10:dddddddd
# ['9:10:ddddddddd', '8:9:l', '8:11:r']
# 8:5:dd
# ['9:5:ddd']
# 0:7:rrr
# ['0:8:rrrr']
# 0:8:rrrr
# ['1:8:d', '0:9:rrrrr']
# 0:9:rrrrr
# ['1:9:d', '0:10:rrrrrr']
# 10:5:d
# ['11:5:dd']
# 1:5:r
# ['1:6:rr']
# 1:5:uuu
# ['0:5:uuuu']
# 4:0:u
# ['3:0:uu']
# 4:5:ll
# ['4:4:lll']
# 4:5:lll
# ['4:4:llll']
# 5:4:ll
# ['5:3:lll']
# 5:8:ll
# ['5:7:lll']
# 5:8:r
# ['5:9:rr']
# 6:7:dddddd
# ['7:7:ddddddd', '6:6:l', '6:8:r']
# 7:0:dd
# ['8:0:ddd']
# 7:5:ddd
# ['8:5:dddd']
# 7:5:u
# ['6:5:uu']
# 8:5:ddd
# ['9:5:dddd']
# 8:5:u
# ['7:5:uu']
# 0:2:ll
# ['0:1:lll']
# 0:4:uuuuu
# ['0:3:l', '0:5:r']
# 11:4:ddd
# ['12:4:dddd']
# 12:4:ddd
# []
# 3:4:uuu
# ['2:4:uuuu']
# 4:10:rrr
# ['4:11:rrrr']
# 4:11:rrrrr
# ['3:11:u', '5:11:d', '4:12:rrrrrr']
# 5:3:ll
# ['5:2:lll']
# 5:6:l
# ['5:5:ll']
# 5:8:d
# ['6:8:dd']
# 6:1:lll
# ['6:0:llll']
# 6:4:l
# ['6:3:ll']
# 6:7:rrr
# ['6:8:rrrr']
# 6:7:rrrrrrr
# ['5:7:u', '7:7:d', '6:8:rrrrrrrr']
# 7:2:ll
# ['7:1:lll']
# 7:6:dd
# ['8:6:ddd']
# 7:6:rr
# ['7:7:rrr']
# 7:9:ddddddd
# ['8:9:dddddddd', '7:8:l', '7:10:r']
# 8:6:dddddddd
# ['9:6:ddddddddd', '8:5:l', '8:7:r']
# 9:5:dd
# ['10:5:ddd']
# 9:6:rrrrrr
# ['8:6:u', '10:6:d', '9:7:rrrrrrr']
# 0:10:rrrrrr
# ['1:10:d', '0:11:rrrrrrr']
# 10:4:ddd
# ['11:4:dddd']
# 12:6:dd
# []
# 1:3:l
# ['1:2:ll']
# 1:6:rr
# ['1:7:rrr']
# 1:6:uuu
# ['0:6:uuuu']
# 2:0:uu
# ['1:0:uuu']
# 2:12:uu
# ['1:12:uuu']
# 3:7:u
# ['2:7:uu']
# 4:2:llll
# ['3:2:u', '5:2:d', '4:1:lllll']
# 4:7:lll
# ['4:6:llll']
# 4:9:rrrr
# ['3:9:u', '5:9:d', '4:10:rrrrr']
# 5:10:d
# ['6:10:dd']
# 5:12:rrrr
# ['4:12:u', '6:12:d']
# 5:6:ll
# ['5:5:lll']
# 5:6:u
# ['4:6:uu']
# 6:12:dd
# ['7:12:ddd']
# 6:7:l
# ['6:6:ll']
# 6:8:l
# ['6:7:ll']
# 7:9:l
# ['7:8:ll']
# 8:0:dddd
# ['9:0:ddddd', '8:1:r']
# 8:3:l
# ['8:2:ll']
# 8:4:dddd
# ['9:4:ddddd', '8:3:l', '8:5:r']
# 8:5:r
# ['8:6:rr']
# 8:5:uu
# ['7:5:uuu']
# 8:6:d
# ['9:6:dd']
# 9:10:ddddddddd
# ['10:10:dddddddddd', '9:9:l', '9:11:r']
# 9:4:ddd
# ['10:4:dddd']
# 9:4:dddd
# ['10:4:ddddd', '9:3:l', '9:5:r']
# 9:4:ddddddddd
# ['10:4:dddddddddd', '9:3:l', '9:5:r']
# 9:6:u
# ['8:6:uu']
# 0:11:rrrrrrr
# ['1:11:d', '0:12:rrrrrrrr']
# 11:5:dd
# ['12:5:ddd']
# 2:5:uuu
# ['1:5:uuuu']
# 4:10:rrrrrr
# ['3:10:u', '5:10:d', '4:11:rrrrrrr']
# 4:11:rrrr
# ['3:11:u', '5:11:d', '4:12:rrrrr']
# 4:1:llll
# ['3:1:u', '5:1:d', '4:0:lllll']
# 6:6:u
# ['5:6:uu']
# 7:5:l
# ['7:4:ll']
# 7:7:r
# ['7:8:rr']
# 8:0:ddd
# ['9:0:dddd']
# 8:5:dddddddd
# ['9:5:ddddddddd', '8:4:l', '8:6:r']
# 0:5:uuuu
# ['0:4:l', '0:6:r']
# 10:8:rrrrrrrr
# ['9:8:u', '11:8:d', '10:9:rrrrrrrrr']
# 1:11:d
# ['2:11:dd']
# 1:2:ll
# ['1:1:lll']
# 2:4:uuuu
# ['1:4:uuuuu', '2:3:l', '2:5:r']
# 2:8:uu
# ['1:8:uuu']
# 3:0:uu
# ['2:0:uuu']
# 3:10:u
# ['2:10:uu']
# 3:6:uu
# ['2:6:uuu']
# 4:5:uu
# ['3:5:uuu']
# 4:6:lll
# ['4:5:llll']
# 4:9:rrrrrrrrr
# ['3:9:u', '5:9:d', '4:10:rrrrrrrrrr']
# 5:2:d
# ['6:2:dd']
# 5:8:rrrr
# ['4:8:u', '6:8:d', '5:9:rrrrr']
# 5:8:rrrrrrrr
# ['4:8:u', '6:8:d', '5:9:rrrrrrrrr']
# 6:10:rr
# ['6:11:rrr']
# 6:11:rr
# ['6:12:rrr']
# 6:7:d
# ['7:7:dd']
# 6:8:ll
# ['6:7:lll']
# 6:8:rr
# ['6:9:rrr']
# 7:12:ddd
# ['8:12:dddd']
# 7:6:ddd
# ['8:6:dddd']
# 7:6:r
# ['7:7:rr']
# 7:7:rrrrrrr
# ['6:7:u', '8:7:d', '7:8:rrrrrrrr']
# 0:12:rrrrrrrr
# ['1:12:d']
# 0:6:r
# ['0:7:rr']
# 0:6:uuuu
# ['0:5:l', '0:7:r']
# 10:5:dd
# ['11:5:ddd']
# 3:9:u
# ['2:9:uu']
# 4:11:rrrrrrr
# ['3:11:u', '5:11:d', '4:12:rrrrrrrr']
# 4:7:u
# ['3:7:uu']
# 5:11:d
# ['6:11:dd']
# 5:2:lll
# ['5:1:llll']
# 5:7:ll
# ['5:6:lll']
# 5:9:rrr
# ['5:10:rrrr']
# 6:4:uu
# ['5:4:uuu']
# 6:7:rr
# ['6:8:rrr']
# 8:5:dddd
# ['9:5:ddddd', '8:4:l', '8:6:r']
# 8:6:dd
# ['9:6:ddd']
# 8:8:dddddddd
# ['9:8:ddddddddd', '8:7:l', '8:9:r']
# 9:0:ddddd
# ['10:0:dddddd', '9:1:r']
# 10:0:dddddd
# ['11:0:ddddddd', '10:1:r']
# 9:5:ddd
# ['10:5:dddd']
# 0:1:lll
# ['0:0:llll']
# 10:10:dddddddddd
# ['10:9:l', '10:11:r']
# 10:6:d
# ['11:6:dd']
# 11:0:ddddddd
# ['12:0:dddddddd', '11:1:r']
# 11:4:dddd
# ['12:4:ddddd', '11:3:l', '11:5:r']
# 11:7:d
# ['12:7:dd']
# 12:4:dddd
# ['12:3:l', '12:5:r']
# 1:0:uuu
# ['0:0:uuuu']
# 1:12:uuu
# ['0:12:uuuu']
# 1:7:rrr
# ['1:8:rrrr']
# 4:10:rrrrr
# ['3:10:u', '5:10:d', '4:11:rrrrrr']
# 4:12:rrrrrr
# ['3:12:u', '5:12:d']
# 4:4:uuu
# ['3:4:uuuu']
# 5:1:d
# ['6:1:dd']
# 5:9:d
# ['6:9:dd']
# 6:0:llll
# ['5:0:u', '7:0:d']
# 6:4:ll
# ['6:3:lll']
# 7:10:r
# ['7:11:rr']
# 7:4:uu
# ['6:4:uuu']
# 7:4:uuu
# ['6:4:uuuu']
# 7:6:u
# ['6:6:uu']
# 7:9:r
# ['7:10:rr']
# 8:11:r
# ['8:12:rr']
# 8:7:rrrrrrr
# ['7:7:u', '9:7:d', '8:8:rrrrrrrr']
# 8:9:dddddddd
# ['9:9:ddddddddd', '8:8:l', '8:10:r']
# 8:9:l
# ['8:8:ll']
# 9:0:dddd
# ['10:0:ddddd', '9:1:r']
# 10:0:ddddd
# ['11:0:dddddd', '10:1:r']
# 9:11:r
# ['9:12:rr']
# 9:5:dddd
# ['10:5:ddddd', '9:4:l', '9:6:r']
# 9:6:d
# ['10:6:dd']
# 0:7:r
# ['0:8:rr']
# 0:7:rr
# ['0:8:rrr']
# 0:8:rr
# ['0:9:rrr']
# 0:8:rrr
# ['0:9:rrrr']
# 0:9:rrr
# ['0:10:rrrr']
# 0:9:rrrr
# ['1:9:d', '0:10:rrrrr']
# 10:4:dddd
# ['11:4:ddddd', '10:3:l', '10:5:r']
# 10:4:ddddd
# ['11:4:dddddd', '10:3:l', '10:5:r']
# 10:4:dddddddddd
# ['10:3:l', '10:5:r']
# 11:0:dddddd
# ['12:0:ddddddd', '11:1:r']
# 1:12:d
# ['2:12:dd']
# 1:1:lll
# ['1:0:llll']
# 2:10:uu
# ['1:10:uuu']
# 2:5:r
# ['2:6:rr']
# 3:11:u
# ['2:11:uu']
# 3:2:u
# ['2:2:uu']
# 4:4:lll
# ['4:3:llll']
# 4:4:llll
# ['3:4:u', '5:4:d', '4:3:lllll']
# 5:8:rrr
# ['5:9:rrrr']
# 5:9:rr
# ['5:10:rrr']
# 6:12:d
# ['7:12:dd']
# 6:6:l
# ['6:5:ll']
# 6:7:dd
# ['7:7:ddd']
# 6:8:r
# ['6:9:rr']
# 7:4:l
# ['7:3:ll']
# 8:6:ddd
# ['9:6:dddd']
# 9:3:l
# ['9:2:ll']
# 9:4:ddddd
# ['10:4:dddddd', '9:3:l', '9:5:r']
# 10:5:ddd
# ['11:5:dddd']
# 10:9:rrrrrrrrr
# ['9:9:u', '11:9:d', '10:10:rrrrrrrrrr']
# 11:5:ddd
# ['12:5:dddd']
# 1:8:rrrr
# ['0:8:u', '2:8:d', '1:9:rrrrr']
# 1:8:uuu
# ['0:8:uuuu']
# 2:0:uuu
# ['1:0:uuuu']
# 2:11:dd
# ['3:11:ddd']
# 3:1:u
# ['2:1:uu']
# 4:0:lllll
# ['3:0:u', '5:0:d']
# 4:10:rrrrrrrrrr
# ['3:10:u', '5:10:d']
# 4:11:rrrrrr
# ['3:11:u', '5:11:d', '4:12:rrrrrrr']
# 4:12:rrrrr
# ['3:12:u', '5:12:d']
# 4:1:lllll
# ['3:1:u', '5:1:d', '4:0:llllll']
# 5:0:u
# ['4:0:uu']
# 5:10:rrrr
# ['4:10:u', '6:10:d', '5:11:rrrrr']
# 5:5:uu
# ['4:5:uuu']
# 5:7:lll
# ['5:6:llll']
# 6:10:dd
# ['7:10:ddd']
# 6:2:dd
# ['7:2:ddd']
# 6:5:uu
# ['5:5:uuu']
# 6:8:dd
# ['7:8:ddd']
# 6:8:rrrr
# ['5:8:u', '7:8:d', '6:9:rrrrr']
# 6:8:rrrrrrrr
# ['5:8:u', '7:8:d', '6:9:rrrrrrrrr']
# 7:0:d
# ['8:0:dd']
# 7:1:lll
# ['7:0:llll']
# 7:5:uu
# ['6:5:uuu']
# 7:7:ddddddd
# ['8:7:dddddddd', '7:6:l', '7:8:r']
# 7:7:l
# ['7:6:ll']
# 8:2:ll
# ['8:1:lll']
# 8:5:l
# ['8:4:ll']
# 8:6:rr
# ['8:7:rrr']
# 9:12:rr
# []
# 9:5:r
# ['9:6:rr']
# 0:0:llll
# ['1:0:d']
# 0:0:uuuu
# ['0:1:r']
# 0:10:rrrr
# ['1:10:d', '0:11:rrrrr']
# 0:10:rrrrr
# ['1:10:d', '0:11:rrrrrr']
# 0:4:l
# ['0:3:ll']
# 0:5:l
# ['0:4:ll']
# 11:5:r
# ['11:6:rr']
# 12:0:dddddddd
# ['12:1:r']
# 12:3:l
# ['12:2:ll']
# 12:5:ddd
# []
# 1:4:uuuuu
# ['0:4:uuuuuu', '1:3:l', '1:5:r']
# 1:5:uuuu
# ['0:5:uuuuu', '1:4:l', '1:6:r']
# 2:7:uu
# ['1:7:uuu']
# 4:12:u
# ['3:12:uu']
# 5:3:lll
# ['5:2:llll']
# 5:7:u
# ['4:7:uu']
# 6:11:rrr
# ['6:12:rrrr']
# 6:12:rrr
# []
# 6:1:dd
# ['7:1:ddd']
# 6:3:ll
# ['6:2:lll']
# 6:6:ll
# ['6:5:lll']
# 7:12:dd
# ['8:12:ddd']
# 7:7:d
# ['8:7:dd']
# 7:7:rrr
# ['7:8:rrrr']
# 7:8:l
# ['7:7:ll']
# 7:8:rr
# ['7:9:rrr']
# 8:6:r
# ['8:7:rr']
# 8:6:u
# ['7:6:uu']
# 8:7:r
# ['8:8:rr']
# 9:5:ddddddddd
# ['10:5:dddddddddd', '9:4:l', '9:6:r']
# 9:6:ddddddddd
# ['10:6:dddddddddd', '9:5:l', '9:7:r']
# 9:7:rrrrrrr
# ['8:7:u', '10:7:d', '9:8:rrrrrrrr']
# 9:7:u
# ['8:7:uu']
# 9:9:l
# ['9:8:ll']
# 0:11:rrrrr
# ['1:11:d', '0:12:rrrrrr']
# 0:11:rrrrrr
# ['1:11:d', '0:12:rrrrrrr']
# 0:12:uuuu
# ['0:11:l']
# 0:8:u
# []
# 0:8:uuuu
# ['0:7:l', '0:9:r']
# 0:9:r
# ['0:10:rr']
# 11:1:r
# ['11:2:rr']
# 12:0:ddddddd
# ['12:1:r']
# 2:12:dd
# ['3:12:ddd']
# 2:3:l
# ['2:2:ll']
# 2:6:uuu
# ['1:6:uuuu']
# 2:9:uu
# ['1:9:uuu']
# 4:12:rrrrrrrr
# ['3:12:u', '5:12:d']
# 4:5:llll
# ['3:5:u', '5:5:d', '4:4:lllll']
# 4:6:llll
# ['3:6:u', '5:6:d', '4:5:lllll']
# 4:6:uu
# ['3:6:uuu']
# 5:10:rrr
# ['5:11:rrrr']
# 5:1:llll
# ['4:1:u', '6:1:d', '5:0:lllll']
# 6:11:dd
# ['7:11:ddd']
# 6:9:rrr
# ['6:10:rrrr']
# 7:11:rr
# ['7:12:rrr']
# 7:2:ddd
# ['8:2:dddd']
# 7:5:uuu
# ['6:5:uuuu']
# 7:8:ll
# ['7:7:lll']
# 7:8:rrrrrrrr
# ['6:8:u', '8:8:d', '7:9:rrrrrrrrr']
# 8:12:dddd
# ['9:12:ddddd', '8:11:l']
# 8:6:dddd
# ['9:6:ddddd', '8:5:l', '8:7:r']
# 8:6:uu
# ['7:6:uuu']
# 8:9:r
# ['8:10:rr']
# 9:6:dd
# ['10:6:ddd']
# 10:11:r
# ['10:12:rr']
# 10:6:dd
# ['11:6:ddd']
# 11:4:ddddd
# ['12:4:dddddd', '11:3:l', '11:5:r']
# 11:4:dddddd
# ['12:4:ddddddd', '11:3:l', '11:5:r']
# 11:5:dddd
# ['12:5:ddddd', '11:4:l', '11:6:r']
# 11:8:d
# ['12:8:dd']
# 12:1:r
# ['12:2:rr']
# 12:4:ddddd
# ['12:3:l', '12:5:r']
# 12:7:dd
# []
# 1:0:llll
# ['0:0:u', '2:0:d']
# 1:6:r
# ['1:7:rr']
# 2:1:uu
# ['1:1:uuu']
# 2:6:rr
# ['2:7:rrr']
# 3:12:ddd
# ['4:12:dddd']
# 4:8:u
# ['3:8:uu']
# 5:4:uuu
# ['4:4:uuuu']
# 5:5:ll
# ['5:4:lll']
# 5:9:rrrrr
# ['4:9:u', '6:9:d', '5:10:rrrrrr']
# 5:9:rrrrrrrrr
# ['4:9:u', '6:9:d', '5:10:rrrrrrrrrr']
# 6:8:d
# ['7:8:dd']
# 7:10:rr
# ['7:11:rrr']
# 8:0:dd
# ['9:0:ddd']
# 9:5:ddddd
# ['10:5:dddddd', '9:4:l', '9:6:r']
# 9:9:ddddddddd
# ['10:9:dddddddddd', '9:8:l', '9:10:r']
# 0:10:rr
# ['0:11:rrr']
# 0:12:rrrrrr
# ['1:12:d']
# 0:12:rrrrrrr
# ['1:12:d']
# 10:10:rrrrrrrrrr
# ['9:10:u', '11:10:d']
# 10:3:l
# ['10:2:ll']
# 10:4:dddddd
# ['11:4:ddddddd', '10:3:l', '10:5:r']
# 10:5:dddd
# ['11:5:ddddd', '10:4:l', '10:6:r']
# 10:9:l
# ['10:8:ll']
# 12:2:ll
# ['12:1:lll']
# 12:2:rr
# ['12:3:rrr']
# 12:5:r
# ['12:6:rr']
# 1:0:uuuu
# ['0:0:uuuuu', '1:1:r']
# 1:9:rrrrr
# ['0:9:u', '2:9:d', '1:10:rrrrrr']
# 2:8:d
# ['3:8:dd']
# 3:11:ddd
# ['4:11:dddd']
# 3:12:uu
# ['2:12:uuu']
# 3:4:uuuu
# ['2:4:uuuuu', '3:3:l', '3:5:r']
# 5:0:lllll
# ['4:0:u', '6:0:d']
# 5:11:rrrrr
# ['4:11:u', '6:11:d', '5:12:rrrrrr']
# 5:5:lll
# ['5:4:llll']
# 5:6:uu
# ['4:6:uuu']
# 6:7:ll
# ['6:6:lll']
# 6:8:rrr
# ['6:9:rrrr']
# 6:9:dd
# ['7:9:ddd']
# 7:0:llll
# ['6:0:u', '8:0:d']
# 7:12:rrr
# []
# 7:4:ll
# ['7:3:lll']
# 7:7:dd
# ['8:7:ddd']
# 7:7:rr
# ['7:8:rrr']
# 8:12:rr
# []
# 8:7:d
# ['9:7:dd']
# 9:12:ddddd
# ['10:12:dddddd', '9:11:l']
# 9:8:ddddddddd
# ['10:8:dddddddddd', '9:7:l', '9:9:r']
# 0:11:l
# ['0:10:ll']
# 0:11:rrr
# ['0:12:rrrr']
# 0:3:ll
# ['0:2:lll']
# 0:5:uuuuu
# ['0:4:l', '0:6:r']
# 10:12:rr
# []
# 10:5:ddddd
# ['11:5:dddddd', '10:4:l', '10:6:r']
# 11:2:rr
# ['11:3:rrr']
# 11:3:l
# ['11:2:ll']
# 11:6:dd
# ['12:6:ddd']
# 12:3:rrr
# ['12:4:rrrr']
# 1:1:r
# ['1:2:rr']
# 1:2:rr
# ['1:3:rrr']
# 2:0:d
# ['3:0:dd']
# 2:11:uu
# ['1:11:uuu']
# 2:2:uu
# ['1:2:uuu']
# 3:5:uuu
# ['2:5:uuuu']
# 4:0:llllll
# ['3:0:u', '5:0:d']
# 4:0:uu
# ['3:0:uuu']
# 4:12:rrrrrrr
# ['3:12:u', '5:12:d']
# 5:2:llll
# ['4:2:u', '6:2:d', '5:1:lllll']
# 6:1:d
# ['7:1:dd']
# 6:6:uu
# ['5:6:uuu']
# 6:9:rr
# ['6:10:rrr']
# 7:10:ddd
# ['8:10:dddd']
# 8:10:r
# ['8:11:rr']
# 8:4:l
# ['8:3:ll']
# 8:8:rrrrrrrr
# ['7:8:u', '9:8:d', '8:9:rrrrrrrrr']
# 9:4:l
# ['9:3:ll']
# 9:6:ddd
# ['10:6:dddd']
# 9:8:u
# ['8:8:uu']
# 0:0:u
# []
# 0:4:ll
# ['0:3:lll']
# 0:4:uuuuuu
# ['0:3:l', '0:5:r']
# 0:7:l
# ['0:6:ll']
# 0:9:u
# []
# 10:12:dddddd
# ['11:12:ddddddd', '10:11:l']
# 10:5:r
# ['10:6:rr']
# 10:6:dddddddddd
# ['10:5:l', '10:7:r']
# 11:9:d
# ['12:9:dd']
# 12:5:dddd
# ['12:4:l', '12:6:r']
# 1:10:uuu
# ['0:10:uuuu']
# 1:1:uuu
# ['0:1:uuuu']
# 1:4:l
# ['1:3:ll']
# 1:6:uuuu
# ['0:6:uuuuu', '1:5:l', '1:7:r']
# 3:7:uu
# ['2:7:uuu']
# 4:10:u
# ['3:10:uu']
# 4:11:dddd
# ['5:11:ddddd', '4:10:l', '4:12:r']
# 4:3:llll
# ['3:3:u', '5:3:d', '4:2:lllll']
# 4:3:lllll
# ['3:3:u', '5:3:d', '4:2:llllll']
# 4:5:uuu
# ['3:5:uuuu']
# 5:10:rrrrrr
# ['4:10:u', '6:10:d', '5:11:rrrrrrr']
# 5:10:rrrrrrrrrr
# ['4:10:u', '6:10:d']
# 5:11:rrrr
# ['4:11:u', '6:11:d', '5:12:rrrrr']
# 5:6:lll
# ['5:5:llll']
# 5:9:rrrr
# ['4:9:u', '6:9:d', '5:10:rrrrr']
# 6:10:d
# ['7:10:dd']
# 6:12:rrrr
# ['5:12:u', '7:12:d']
# 6:3:lll
# ['6:2:llll']
# 6:7:lll
# ['6:6:llll']
# 6:7:u
# ['5:7:uu']
# 6:9:rrrrr
# ['5:9:u', '7:9:d', '6:10:rrrrrr']
# 6:9:rrrrrrrrr
# ['5:9:u', '7:9:d', '6:10:rrrrrrrrrr']
# 7:11:ddd
# ['8:11:dddd']
# 7:1:ddd
# ['8:1:dddd']
# 7:8:d
# ['8:8:dd']
# 7:8:ddd
# ['8:8:dddd']
# 7:8:r
# ['7:9:rr']
# 8:2:dddd
# ['9:2:ddddd', '8:1:l', '8:3:r']
# 9:0:ddd
# ['10:0:dddd']
# 10:0:dddd
# ['11:0:ddddd', '10:1:r']
# 9:10:r
# ['9:11:rr']
# 9:2:ll
# ['9:1:lll']
# 9:6:r
# ['9:7:rr']
# 9:7:d
# ['10:7:dd']
# 0:0:uuuuu
# ['0:1:r']
# 0:12:rrrr
# ['1:12:d']
# 0:2:lll
# ['0:1:llll']
# 10:2:ll
# ['10:1:lll']
# 10:6:ddd
# ['11:6:dddd']
# 10:9:dddddddddd
# ['10:8:l', '10:10:r']
# 11:0:ddddd
# ['12:0:dddddd', '11:1:r']
# 11:5:ddddd
# ['12:5:dddddd', '11:4:l', '11:6:r']
# 12:6:rr
# ['12:7:rrr']
# 12:8:dd
# []
# 1:2:uuu
# ['0:2:uuuu']
# 1:7:rr
# ['1:8:rrr']
# 1:7:uuu
# ['0:7:uuuu']
# 2:4:uuuuu
# ['1:4:uuuuuu', '2:3:l', '2:5:r']
# 2:9:d
# ['3:9:dd']
# 3:0:dd
# ['4:0:ddd']
# 3:8:dd
# ['4:8:ddd']
# 5:12:rrrrrr
# ['4:12:u', '6:12:d']
# 6:2:lll
# ['6:1:llll']
# 6:4:uuu
# ['5:4:uuuu']
# 6:4:uuuu
# ['5:4:uuuuu', '6:3:l', '6:5:r']
# 6:5:ll
# ['6:4:lll']
# 7:11:rrr
# ['7:12:rrrr']
# 7:3:ll
# ['7:2:lll']
# 7:7:ddd
# ['8:7:dddd']
# 7:8:rrrr
# ['6:8:u', '8:8:d', '7:9:rrrrr']
# 8:0:d
# ['9:0:dd']
# 8:12:ddd
# ['9:12:dddd']
# 8:1:lll
# ['8:0:llll']
# 8:7:l
# ['8:6:ll']
# 8:8:l
# ['8:7:ll']
# 8:8:ll
# ['8:7:lll']
# 9:6:dddd
# ['10:6:ddddd', '9:5:l', '9:7:r']
# 9:9:u
# ['8:9:uu']
# 10:5:dddddddddd
# ['10:4:l', '10:6:r']
# 10:7:d
# ['11:7:dd']
# 11:4:ddddddd
# ['12:4:dddddddd', '11:3:l', '11:5:r']
# 11:5:dddddd
# ['12:5:ddddddd', '11:4:l', '11:6:r']
# 11:6:rr
# ['11:7:rrr']
# 12:1:lll
# ['12:0:llll']
# 12:4:dddddd
# ['12:3:l', '12:5:r']
# 12:4:ddddddd
# ['12:3:l', '12:5:r']
# 12:6:ddd
# []
# 1:11:uuu
# ['0:11:uuuu']
# 1:9:uuu
# ['0:9:uuuu']
# 2:2:ll
# ['2:1:lll']
# 2:7:rrr
# ['2:8:rrrr']
# 3:6:uuu
# ['2:6:uuuu']
# 3:8:uu
# ['2:8:uuu']
# 4:11:u
# ['3:11:uu']
# 4:12:dddd
# ['5:12:ddddd', '4:11:l']
# 4:1:u
# ['3:1:uu']
# 4:5:lllll
# ['3:5:u', '5:5:d', '4:4:llllll']
# 6:10:rrrr
# ['5:10:u', '7:10:d', '6:11:rrrrr']
# 6:5:uuu
# ['5:5:uuuu']
# 7:12:d
# ['8:12:dd']
# 7:6:l
# ['7:5:ll']
# 7:6:ll
# ['7:5:lll']
# 7:7:u
# ['6:7:uu']
# 8:7:dddddddd
# ['9:7:ddddddddd', '8:6:l', '8:8:r']
# 8:7:rrr
# ['8:8:rrrr']
# 8:8:rr
# ['8:9:rrr']
# 9:6:rr
# ['9:7:rrr']
# 9:8:rrrrrrrr
# ['8:8:u', '10:8:d', '9:9:rrrrrrrrr']
# 0:10:ll
# ['0:9:lll']
# 0:2:uuuu
# ['0:1:l', '0:3:r']
# 0:6:ll
# ['0:5:lll']
# 0:6:uuuuu
# ['0:5:l', '0:7:r']
# 10:6:r
# ['10:7:rr']
# 10:8:dddddddddd
# ['10:7:l', '10:9:r']
# 11:4:l
# ['11:3:ll']
# 12:5:ddddd
# ['12:4:l', '12:6:r']
# 12:6:r
# ['12:7:rr']
# 1:10:rrrrrr
# ['0:10:u', '2:10:d', '1:11:rrrrrrr']
# 1:3:rrr
# ['1:4:rrrr']
# 1:8:rrr
# ['1:9:rrrr']
# 2:12:uuu
# ['1:12:uuuu']
# 3:0:uuu
# ['2:0:uuuu']
# 4:4:lllll
# ['3:4:u', '5:4:d', '4:3:llllll']
# 5:10:rrrrr
# ['4:10:u', '6:10:d', '5:11:rrrrrr']
# 5:12:rrrrr
# ['4:12:u', '6:12:d']
# 5:4:lll
# ['5:3:llll']
# 5:6:llll
# ['4:6:u', '6:6:d', '5:5:lllll']
# 6:0:u
# ['5:0:uu']
# 6:11:d
# ['7:11:dd']
# 6:2:d
# ['7:2:dd']
# 6:5:lll
# ['6:4:llll']
# 6:9:d
# ['7:9:dd']
# 7:12:rrrr
# ['6:12:u', '8:12:d']
# 7:6:uu
# ['6:6:uuu']
# 7:8:dd
# ['8:8:ddd']
# 7:9:rrr
# ['7:10:rrrr']
# 8:10:rr
# ['8:11:rrr']
# 8:3:r
# ['8:4:rr']
# 8:7:dd
# ['9:7:ddd']
# 8:7:rr
# ['8:8:rrr']
# 8:8:d
# ['9:8:dd']
# 9:10:u
# ['8:10:uu']
# 9:12:dddd
# ['10:12:ddddd', '9:11:l']
# 9:5:l
# ['9:4:ll']
# 9:7:r
# ['9:8:rr']
# 9:9:r
# ['9:10:rr']
# 0:10:uuuu
# ['0:9:l', '0:11:r']
# 0:3:lll
# ['0:2:llll']
# 0:9:uuuu
# ['0:8:l', '0:10:r']
# 10:1:lll
# ['10:0:llll']
# 10:5:dddddd
# ['11:5:ddddddd', '10:4:l', '10:6:r']
# 10:6:dddd
# ['11:6:ddddd', '10:5:l', '10:7:r']
# 11:10:d
# ['12:10:dd']
# 11:12:ddddddd
# ['12:12:dddddddd', '11:11:l']
# 11:2:ll
# ['11:1:lll']
# 11:3:rrr
# ['11:4:rrrr']
# 11:6:ddd
# ['12:6:dddd']
# 11:6:r
# ['11:7:rr']
# 12:0:dddddd
# ['12:1:r']
# 12:4:rrrr
# ['11:4:u', '12:5:rrrrr']
# 12:9:dd
# []
# 1:11:rrrrrrr
# ['0:11:u', '2:11:d', '1:12:rrrrrrrr']
# 1:7:r
# ['1:8:rr']
# 2:10:d
# ['3:10:dd']
# 2:5:uuuu
# ['1:5:uuuuu', '2:4:l', '2:6:r']
# 4:0:ddd
# ['5:0:dddd']
# 4:2:u
# ['3:2:uu']
# 4:4:uuuu
# ['3:4:uuuuu', '4:3:l', '4:5:r']
# 4:7:uu
# ['3:7:uuu']
# 5:0:dddd
# ['6:0:ddddd', '5:1:r']
# 5:11:ddddd
# ['6:11:dddddd', '5:10:l', '5:12:r']
# 5:11:rrrrrrr
# ['4:11:u', '6:11:d', '5:12:rrrrrrrr']
# 5:1:lllll
# ['4:1:u', '6:1:d', '5:0:llllll']
# 5:4:llll
# ['4:4:u', '6:4:d', '5:3:lllll']
# 5:5:uuu
# ['4:5:uuuu']
# 5:8:u
# ['4:8:uu']
# 6:5:uuuu
# ['5:5:uuuuu', '6:4:l', '6:6:r']
# 6:9:rrrr
# ['5:9:u', '7:9:d', '6:10:rrrrr']
# 7:1:dd
# ['8:1:ddd']
# 7:6:uuu
# ['6:6:uuuu']
# 7:8:rrr
# ['7:9:rrrr']
# 7:9:rrrrrrrrr
# ['6:9:u', '8:9:d', '7:10:rrrrrrrrrr']
# 8:3:ll
# ['8:2:lll']
# 8:4:ll
# ['8:3:lll']
# 8:9:rrrrrrrrr
# ['7:9:u', '9:9:d', '8:10:rrrrrrrrrr']
# 9:0:dd
# ['10:0:ddd']
# 10:0:ddd
# ['11:0:dddd']
# 9:11:l
# ['9:10:ll']
# 9:11:rr
# ['9:12:rrr']
# 9:3:ll
# ['9:2:lll']
# 9:6:ddddd
# ['10:6:dddddd', '9:5:l', '9:7:r']
# 9:8:ll
# ['9:7:lll']
# 0:11:r
# ['0:12:rr']
# 0:11:uuuu
# ['0:10:l', '0:12:r']
# 0:1:uuuu
# ['0:0:l', '0:2:r']
# 0:2:r
# ['0:3:rr']
# 0:3:r
# ['0:4:rr']
# 0:7:uuuu
# ['0:6:l', '0:8:r']
# 0:8:r
# ['0:9:rr']
# 0:9:lll
# ['0:8:llll']
# 0:9:rr
# ['0:10:rrr']
# 10:10:r
# ['10:11:rr']
# 10:12:ddddd
# ['11:12:dddddd', '10:11:l']
# 10:4:l
# ['10:3:ll']
# 10:6:rr
# ['10:7:rrr']
# 10:8:ll
# ['10:7:lll']
# 11:0:dddd
# ['12:0:ddddd', '11:1:r']
# 2:1:lll
# ['2:0:llll']
# 3:10:uu
# ['2:10:uuu']
# 3:3:l
# ['3:2:ll']
# 3:5:r
# ['3:6:rr']
# 3:9:dd
# ['4:9:ddd']
# 4:12:r
# []
# 4:2:lllll
# ['3:2:u', '5:2:d', '4:1:llllll']
# 4:2:llllll
# ['3:2:u', '5:2:d', '4:1:lllllll']
# 4:9:u
# ['3:9:uu']
# 5:0:uu
# ['4:0:uuu']
# 5:12:ddddd
# ['6:12:dddddd', '5:11:l']
# 5:12:u
# ['4:12:uu']
# 6:10:rrr
# ['6:11:rrrr']
# 6:6:lll
# ['6:5:llll']
# 6:8:u
# ['5:8:uu']
# 7:10:dd
# ['8:10:ddd']
# 7:2:dd
# ['8:2:ddd']
# 7:2:lll
# ['7:1:llll']
# 7:7:ll
# ['7:6:lll']
# 8:11:l
# ['8:10:ll']
# 8:1:dddd
# ['9:1:ddddd', '8:0:l', '8:2:r']
# 8:7:u
# ['7:7:uu']
# 8:7:uu
# ['7:7:uuu']
# 9:2:ddddd
# ['10:2:dddddd', '9:1:l', '9:3:r']
# 0:10:r
# ['0:11:rr']
# 0:1:llll
# ['1:1:d', '0:0:lllll']
# 0:2:llll
# ['1:2:d', '0:1:lllll']
# 0:8:l
# ['0:7:ll']
# 0:9:l
# ['0:8:ll']
# 10:0:llll
# ['9:0:u', '11:0:d']
# 10:2:dddddd
# ['11:2:ddddddd', '10:1:l', '10:3:r']
# 10:6:ddddd
# ['11:6:dddddd', '10:5:l', '10:7:r']
# Yes!

# %%
cost, pth
# Out:
# (102,
#  ['0:0:X',
#   '0:1:r',
#   '0:2:rr',
#   '1:2:d',
#   '1:3:r',
#   '1:4:rr',
#   '1:5:rrr',
#   '0:5:u',
#   '0:6:r',
#   '0:7:rr',
#   '0:8:rrr',
#   '1:8:d',
#   '1:9:r',
#   '2:9:d',
#   '2:10:r',
#   '3:10:d',
#   '4:10:dd',
#   '4:11:r',
#   '5:11:d',
#   '6:11:dd',
#   '7:11:ddd',
#   '7:12:r',
#   '8:12:d',
#   '9:12:dd',
#   '10:12:ddd',
#   '10:11:l',
#   '11:11:d',
#   '12:11:dd',
#   '12:12:r'])

# %%
cost, pth, came_from = astar( puzz )
# Out:
# Yes!

# %%
cost
# Out:
# 914
