# %% [markdown]
# # December 10, 2023
#
# https://adventofcode.com/2023/day/10

# %%
from collections import deque

# %%
test1_str = f'''-L|F7
7S-7|
L|7||
-L-J|
L|-JF'''
test1 = test1_str.split("\n")

test2_str = f'''7-F7-
.FJ|7
SJLL7
|F--J
LJ.LJ'''
test2 = test2_str.split("\n")

# %%
fn = "data/10.txt"
with open(fn, "r") as file:
    text = file.readlines()

puzz = [x.strip() for x in text]

# %%
test
# Out:
# ['-L|F7', '7S-7|', 'L|7||', '-L-J|', 'L|-JF']

# %%
def symbol( cur, maze ):
    return maze[cur[0]][cur[1]]

def find_dirs( s ):
    if s == "F":
        return "down", "right"
    if s == "|":
        return "down", "up"
    if s == "7":
        return "down", "left"
    if s == "J":
        return "up", "left"
    if s == "L":
        return "up", "right" 
    if s == "-":
        return "left", "right"
    if s == ".":
        return None
    raise("Unexpected map symbol", s)

def is_from_dir( cur, last, dir ):
    if dir == "down":
        return last[0] == cur[0]+1 and last[1] == cur[1]
    if dir == "up":
        return last[0] == cur[0]-1 and last[1] == cur[1]
    if dir == "left":
        return last[1] == cur[1]-1 and last[0] == cur[0]
    if dir == "right":
        return last[1] == cur[1]+1 and last[0] == cur[0]
    raise("Unexpected dir", dir)

def go_dir( cur, dir ):
    if dir == "down":
        return cur[0]+1, cur[1]
    if dir == "up":
        return cur[0]-1, cur[1]
    if dir == "left":
        return cur[0], cur[1]-1
    if dir == "right":
        return cur[0], cur[1]+1
    raise("Unexpected dir", dir)
 

def find_next_coord( cur, last, maze ):
    s = symbol( cur, maze )
    if s == ".":
        return None
    dir1, dir2 = find_dirs( s )
    if is_from_dir( cur, last, dir1 ):
        return go_dir( cur, dir2 )
    else:
        return go_dir( cur, dir1 )
    raise("WFAS")

def opp_dir( dir ):
    if dir == "down":
        return "up"
    if dir == "up":
        return "down"
    if dir == "left":
        return "right"
    if dir == "right": 
        return "left"
    raise("Unexpected dir", dir)

def next_move( cur, last, maze ):
    next = find_next_coord( cur, last, maze )

    # edge case: starting from a .
    if next is None:
        return None

    #print("looking at:", next)
    if ( next[0] < 0 or next[0] >= len(maze) or
         next[1] < 0 or next[1] >= len(maze[0]) ):
        return None
    
    next_sym = symbol(next, maze)
    #print( next_sym )
    if next_sym == ".":
        return None
    if next_sym == "S":
        return "S"

    next_dir = find_dirs( next_sym )
    if is_from_dir( next, cur, next_dir[0] ):
        return opp_dir( next_dir[0] )
    if is_from_dir( next, cur, next_dir[1] ):
        return opp_dir( next_dir[1] )
    return None


def travel_path( cur, last, maze, verbose=False ):
    path = [last, cur]

    while True:
        if verbose:
            print(f'''@{cur[0]}, {cur[1]}, {symbol(cur, maze)}''', end='')
        to_go = next_move( cur, last, maze )
        # Can't go that way... dead end!
        if to_go is None:
            if verbose:
                print('\tPATH ENDED!')
            return None
        if verbose:
            print("\tGoing: ", to_go)
        # Back to the start!
        if to_go == "S":
            return path

        last = cur
        cur = go_dir( cur, to_go )
        path.append( cur )

def find_start( maze ):
    for row, line in enumerate(maze):
        if 'S' in line:
            for col, char in enumerate(line):
                if char == 'S':
                    return row, col
    raise( BaseException, 'no S found' )

def find_loop( maze, verbose = False ):
    start = find_start( maze )
    if verbose:
        print("Starting at", *start)
    
    beginnings = ( go_dir(start, 'up'),
                   go_dir(start, 'down'),
                   go_dir(start, 'left'),
                   go_dir(start, 'right')
                )
    for b in beginnings:
        if verbose:
            print("\nTry starting at", *b, )

        # Algo doesn't handle the first check!
        bsym = symbol(b, maze)
        if bsym == ".":
            if verbose:
                print("Can't start at", bsym)
            continue

        bdir1, bdir2 = find_dirs( bsym )
        if not is_from_dir(b, start, bdir1) and not is_from_dir(b, start, bdir2 ):
            if verbose:
                print("Can't start at", bsym, "from this direction")
            continue

        loop = travel_path(b, start, maze, verbose=verbose )
        if loop is not None:
            break
    if loop is None:
        raise( BaseException, 'No loop found!' )
    
    return loop

# %% [markdown]
# ### Part 1

# %%
def part1( maze, verbose=False ):
    loop = find_loop( maze, verbose )
    return int(len(loop)/2)

# %%
part1(test1, verbose=True)
# Out:
# Starting at 1 1
#
# Try starting at 0 1
# Can't start at L from this direction
#
# Try starting at 2 1
# @2, 1, |	Going:  down
# @3, 1, L	Going:  right
# @3, 2, -	Going:  right
# @3, 3, J	Going:  up
# @2, 3, |	Going:  up
# @1, 3, 7	Going:  left
# @1, 2, -	Going:  S
# 4

# %%
part1(test2, verbose=True)
# Out:
# Starting at 2 0
#
# Try starting at 1 0
# Can't start at .
#
# Try starting at 3 0
# @3, 0, |	Going:  down
# @4, 0, L	Going:  right
# @4, 1, J	Going:  up
# @3, 1, F	Going:  right
# @3, 2, -	Going:  right
# @3, 3, -	Going:  right
# @3, 4, J	Going:  up
# @2, 4, 7	Going:  left
# @2, 3, L	Going:  up
# @1, 3, |	Going:  up
# @0, 3, 7	Going:  left
# @0, 2, F	Going:  down
# @1, 2, J	Going:  left
# @1, 1, F	Going:  down
# @2, 1, J	Going:  S
# 8

# %%
part1( puzz, verbose=False )
# Out:
# 7097

# %% [markdown]
# ### Part 2
#
# Not really sure how to go about this...

# %%
def start_pipe_shape( start, loop ):
    one = loop[0]
    two = loop[-1]

    # left-right case: make sure one is on the left of S
    if one[0] == two[0]:
        if one[1] > two[1]:
            tmp=two; two=one; one=tmp
    # otherwise: make sure one is the higher one
    else:
        if one[0] > two[0]:
            tmp=two; two=one; one=tmp

    # Now we have a priority: up, left, right, down and one has higher priority

    if is_from_dir( start, one, "up" ):
        if is_from_dir( start, two, "down"):
            return "|"
        if is_from_dir( start, two, "left"):
            return "J"
        if is_from_dir( start, two, "right"):
            return "L"
    if is_from_dir( start, one, "left" ):
        if is_from_dir( start, two, "right" ):
            return "-"
        if is_from_dir( start, two, "down" ):
            return "7"
    if is_from_dir( start, one, "right" ):
        if is_from_dir( start, two, "down" ):
            return "F"
    raise( BaseException, "couldn't determine start shape")
            


def zoom_map( maze, verbose=False ):
    start = find_start(maze)
    loop = find_loop(maze, verbose)

    ssym = start_pipe_shape( start, loop )

# %%
# Rather than try to figure out discontiguous areas and squeezing through pipes,
# we'll just zoom in and embiggen the space
# This means that the nest interior will be contiguous,
# but we'll have to be careful which spaces we count.

def double( vec ):
    return tuple(2*x for x in vec)

def mean( vec1, vec2 ):
    return tuple( int((x+y)/2) for x,y in zip(vec1, vec2) )

def zoom_loop( loop, verbose=False ):
    big_loop = [ double(loop[0]) ]
    #big_loop = []
    for pos in loop[1:]:
        next = double(pos)
        entre = mean( big_loop[-1], next )
        big_loop += [ entre, next ]

    big_loop.append( mean( big_loop[-1], big_loop[0]) )

    return big_loop

# %%
def neighbors( cur, incl_diag=False ):
    up = go_dir(cur, 'up')
    dwn = go_dir(cur, 'down')
    lft = go_dir(cur, 'left')
    rgt = go_dir(cur, 'right')

    if incl_diag:
        return (
            go_dir(up, 'left'), up, go_dir(up, 'right'),
            lft, rgt,
            go_dir(dwn, 'left'), dwn, go_dir(dwn, 'right'),
        )
    else:
        return (up, lft, rgt, dwn)

def encode( cur ):
    return f'''{cur[0]}:{cur[1]}'''

def decode( chr ):
    return [int(x) for x in chr.split(":")]

def on_edge( pos, maze ):
    # note double the maze dimensions since the coords have been doubled from zoom_loop
    return ( pos[0] <= 0 or pos[1] <= 0 or
             pos[0] >= len(maze)*2 or pos[1] >= len(maze[0])*2 )


def map_interior( loop, maze, verbose=False ):
    loop = sorted( loop )
    start = loop[0]
    beginnings = neighbors( start, incl_diag = True )

        
    for b in beginnings:
        if verbose:
            print("\nbeginning at", *b)

        if b in loop: # oops, not interior!
            if verbose:
                print("part of loop. moving on...")
            continue

        if on_edge( b, maze ):
            if verbose:
                print("this is on the exterior. moving on...")
            continue

        chr = encode(b)
        frontier = set( [chr] )
        room = set( [chr] )
        off_the_grid = False

        while len(frontier) > 0:
            cur_str = frontier.pop()
            cur = decode( cur_str )

            nbrs = neighbors(cur)
            if verbose:
                print("Cur:", cur_str)

            for n in nbrs:
                if verbose:
                    print(*n)
                # check neighbors

                if n in loop:
                    # n isn't part of the space
                    continue

                # "edge" case... we've gone off the grid, this is the room OUTSIDE the loop
                if on_edge( n, maze ):
                    off_the_grid = True
                    break
                # get it? "edge" case... because it's on the edge of the map?

                # otherwise, add it to the room if it's not already there
                # also add it to the frontier because we haven't explored it yet
    
                n_str = encode(n)
                if not n_str in room:
                    room.add( n_str )
                    frontier.add( n_str )
        
        if not off_the_grid:
            # we explored everything, this is the interior room!
            return room
        
        # we reached an edge. that was the exterior
        if verbose:
            print("OFF COURSE!")

    return None

def room_size( room ):
    tot = 0
    for r_str in room:
        # if both coords aren't even, it's an expansion space, not one of the original squares
        r = decode(r_str)
        if (r[0] % 2 == 0) and (r[1] % 2 == 0):
            tot += 1

    return tot

                
def part2( maze, verbose = False ):
    loop = find_loop( maze, verbose )
    zl = zoom_loop( loop, verbose )
    room = map_interior( zl, maze, verbose )
    return room_size( room )

# %%
part2( test1, verbose=True)
# Out:
# Starting at 1 1
#
# Try starting at 0 1
# Can't start at L from this direction
#
# Try starting at 2 1
# @2, 1, |	Going:  down
# @3, 1, L	Going:  right
# @3, 2, -	Going:  right
# @3, 3, J	Going:  up
# @2, 3, |	Going:  up
# @1, 3, 7	Going:  left
# @1, 2, -	Going:  S
#
# beginning at 1 1
# Cur: 1:1
# 0 1
# OFF COURSE!
#
# beginning at 1 2
# Cur: 1:2
# 0 2
# OFF COURSE!
#
# beginning at 1 3
# Cur: 1:3
# 0 3
# OFF COURSE!
#
# beginning at 2 1
# Cur: 2:1
# 1 1
# 2 0
# Cur: 1:1
# 0 1
# OFF COURSE!
#
# beginning at 2 3
# part of loop. moving on...
#
# beginning at 3 1
# Cur: 3:1
# 2 1
# 3 0
# Cur: 2:1
# 1 1
# 2 0
# Cur: 1:1
# 0 1
# OFF COURSE!
#
# beginning at 3 2
# part of loop. moving on...
#
# beginning at 3 3
# Cur: 3:3
# 2 3
# 3 2
# 3 4
# 4 3
# Cur: 4:3
# 3 3
# 4 2
# 4 4
# 5 3
# Cur: 3:4
# 2 4
# 3 3
# 3 5
# 4 4
# Cur: 3:5
# 2 5
# 3 4
# 3 6
# 4 5
# Cur: 4:5
# 3 5
# 4 4
# 4 6
# 5 5
# Cur: 4:4
# 3 4
# 4 3
# 4 5
# 5 4
# Cur: 5:4
# 4 4
# 5 3
# 5 5
# 6 4
# Cur: 5:3
# 4 3
# 5 2
# 5 4
# 6 3
# Cur: 5:5
# 4 5
# 5 4
# 5 6
# 6 5
# 1

# %%
part2(test2, verbose=True )
# Out:
# Starting at 2 0
#
# Try starting at 1 0
# Can't start at .
#
# Try starting at 3 0
# @3, 0, |	Going:  down
# @4, 0, L	Going:  right
# @4, 1, J	Going:  up
# @3, 1, F	Going:  right
# @3, 2, -	Going:  right
# @3, 3, -	Going:  right
# @3, 4, J	Going:  up
# @2, 4, 7	Going:  left
# @2, 3, L	Going:  up
# @1, 3, |	Going:  up
# @0, 3, 7	Going:  left
# @0, 2, F	Going:  down
# @1, 2, J	Going:  left
# @1, 1, F	Going:  down
# @2, 1, J	Going:  S
#
# beginning at -1 3
# this is on the exterior. moving on...
#
# beginning at -1 4
# this is on the exterior. moving on...
#
# beginning at -1 5
# this is on the exterior. moving on...
#
# beginning at 0 3
# this is on the exterior. moving on...
#
# beginning at 0 5
# part of loop. moving on...
#
# beginning at 1 3
# Cur: 1:3
# 0 3
# OFF COURSE!
#
# beginning at 1 4
# part of loop. moving on...
#
# beginning at 1 5
# Cur: 1:5
# 0 5
# 1 4
# 1 6
# 2 5
# Cur: 2:5
# 1 5
# 2 4
# 2 6
# 3 5
# Cur: 3:5
# 2 5
# 3 4
# 3 6
# 4 5
# Cur: 4:5
# 3 5
# 4 4
# 4 6
# 5 5
# Cur: 4:4
# 3 4
# 4 3
# 4 5
# 5 4
# Cur: 5:4
# 4 4
# 5 3
# 5 5
# 6 4
# Cur: 5:3
# 4 3
# 5 2
# 5 4
# 6 3
# Cur: 4:3
# 3 3
# 4 2
# 4 4
# 5 3
# Cur: 3:4
# 2 4
# 3 3
# 3 5
# 4 4
# Cur: 3:3
# 2 3
# 3 2
# 3 4
# 4 3
# Cur: 5:5
# 4 5
# 5 4
# 5 6
# 6 5
# Cur: 5:2
# 4 2
# 5 1
# 5 3
# 6 2
# Cur: 5:6
# 4 6
# 5 5
# 5 7
# 6 6
# Cur: 5:1
# 4 1
# 5 0
# 5 2
# 6 1
# Cur: 5:7
# 4 7
# 5 6
# 5 8
# 6 7
# Cur: 6:1
# 5 1
# 6 0
# 6 2
# 7 1
# Cur: 7:1
# 6 1
# 7 0
# 7 2
# 8 1
# 1

# %%
test3_str = f'''FF7FSF7F7F7F7F7F---7
L|LJ||||||||||||F--J
FL-7LJLJ||||||LJL-77
F--JF--7||LJLJ7F7FJ-
L---JF-JLJ.||-FJLJJ7
|F|F-JF---7F7-L7L|7|
|FFJF7L7F-JF7|JL---7
7-L-JL7||F7|L7F-7F7|
L.L7LFJ|||||FJL7||LJ
L7JLJL-JLJLJL--JLJ.L'''

test3 = test3_str.split("\n")

# %%
part2( test3 )
# Out:
# 10

# %%
part2( puzz, verbose=True )
# Out:
# Starting at 112 18
#
# Try starting at 111 18
# Can't start at J from this direction
#
# Try starting at 113 18
# @113, 18, |	Going:  down
# @114, 18, J	Going:  left
# @114, 17, -	Going:  left
# @114, 16, -	Going:  left
# @114, 15, L	Going:  up
# @113, 15, F	Going:  right
# @113, 16, -	Going:  right
# @113, 17, J	Going:  up
# @112, 17, 7	Going:  left
# @112, 16, -	Going:  left
# @112, 15, -	Going:  left
# @112, 14, L	Going:  up
# @111, 14, F	Going:  right
# @111, 15, -	Going:  right
# @111, 16, J	Going:  up
# @110, 16, F	Going:  right
# @110, 17, 7	Going:  down
# @111, 17, L	Going:  right
# @111, 18, J	Going:  up
# @110, 18, F	Going:  right
# @110, 19, 7	Going:  down
# @111, 19, L	Going:  right
# @111, 20, -	Going:  right
# @111, 21, 7	Going:  down
# @112, 21, L	Going:  right
# @112, 22, J	Going:  up
# @111, 22, F	Going:  right
# @111, 23, 7	Going:  down
# @112, 23, L	Going:  right
# @112, 24, -	Going:  right
# @112, 25, -	Going:  right
# @112, 26, J	Going:  up
# @111, 26, 7	Going:  left
# @111, 25, -	Going:  left
# @111, 24, L	Going:  up
# @110, 24, F	Going:  right
# @110, 25, -	Going:  right
# @110, 26, J	Going:  up
# @109, 26, F	Going:  right
# @109, 27, -	Going:  right
# @109, 28, J	Going:  up
# @108, 28, F	Going:  right
# @108, 29, -	Going:  right
# @108, 30, J	Going:  up
# @107, 30, 7	Going:  left
# @107, 29, -	Going:  left
# @107, 28, -	Going:  left
# @107, 27, F	Going:  down
# @108, 27, J	Going:  left
# @108, 26, L	Going:  up
# @107, 26, 7	Going:  left
# @107, 25, F	Going:  down
# @108, 25, |	Going:  down
# @109, 25, J	Going:  left
# @109, 24, L	Going:  up
# @108, 24, |	Going:  up
# @107, 24, 7	Going:  left
# @107, 23, F	Going:  down
# @108, 23, |	Going:  down
# @109, 23, |	Going:  down
# @110, 23, J	Going:  left
# @110, 22, L	Going:  up
# @109, 22, |	Going:  up
# @108, 22, |	Going:  up
# @107, 22, 7	Going:  left
# @107, 21, F	Going:  down
# @108, 21, |	Going:  down
# @109, 21, |	Going:  down
# @110, 21, J	Going:  left
# @110, 20, L	Going:  up
# @109, 20, 7	Going:  left
# @109, 19, L	Going:  up
# @108, 19, F	Going:  right
# @108, 20, J	Going:  up
# @107, 20, 7	Going:  left
# @107, 19, -	Going:  left
# @107, 18, F	Going:  down
# @108, 18, |	Going:  down
# @109, 18, J	Going:  left
# @109, 17, L	Going:  up
# @108, 17, |	Going:  up
# @107, 17, 7	Going:  left
# @107, 16, F	Going:  down
# @108, 16, |	Going:  down
# @109, 16, J	Going:  left
# @109, 15, L	Going:  up
# @108, 15, |	Going:  up
# @107, 15, 7	Going:  left
# @107, 14, F	Going:  down
# @108, 14, |	Going:  down
# @109, 14, |	Going:  down
# @110, 14, J	Going:  left
# @110, 13, -	Going:  left
# @110, 12, F	Going:  down
# @111, 12, L	Going:  right
# @111, 13, 7	Going:  down
# @112, 13, J	Going:  left
# @112, 12, -	Going:  left
# @112, 11, -	Going:  left
# @112, 10, L	Going:  up
# @111, 10, F	Going:  right
# @111, 11, J	Going:  up
# @110, 11, |	Going:  up
# @109, 11, F	Going:  right
# @109, 12, -	Going:  right
# @109, 13, J	Going:  up
# @108, 13, |	Going:  up
# @107, 13, 7	Going:  left
# @107, 12, -	Going:  left
# @107, 11, L	Going:  up
# @106, 11, 7	Going:  left
# @106, 10, F	Going:  down
# @107, 10, |	Going:  down
# @108, 10, |	Going:  down
# @109, 10, |	Going:  down
# @110, 10, J	Going:  left
# @110, 9, L	Going:  up
# @109, 9, |	Going:  up
# @108, 9, |	Going:  up
# @107, 9, |	Going:  up
# @106, 9, |	Going:  up
# @105, 9, 7	Going:  left
# @105, 8, F	Going:  down
# @106, 8, |	Going:  down
# @107, 8, J	Going:  left
# @107, 7, -	Going:  left
# @107, 6, L	Going:  up
# @106, 6, F	Going:  right
# @106, 7, J	Going:  up
# @105, 7, |	Going:  up
# @104, 7, 7	Going:  left
# @104, 6, L	Going:  up
# @103, 6, 7	Going:  left
# @103, 5, -	Going:  left
# @103, 4, F	Going:  down
# @104, 4, |	Going:  down
# @105, 4, |	Going:  down
# @106, 4, J	Going:  left
# @106, 3, L	Going:  up
# @105, 3, |	Going:  up
# @104, 3, |	Going:  up
# @103, 3, 7	Going:  left
# @103, 2, -	Going:  left
# @103, 1, L	Going:  up
# @102, 1, F	Going:  right
# @102, 2, -	Going:  right
# @102, 3, J	Going:  up
# @101, 3, F	Going:  right
# @101, 4, 7	Going:  down
# @102, 4, L	Going:  right
# @102, 5, J	Going:  up
# @101, 5, F	Going:  right
# @101, 6, 7	Going:  down
# @102, 6, L	Going:  right
# @102, 7, 7	Going:  down
# @103, 7, L	Going:  right
# @103, 8, 7	Going:  down
# @104, 8, L	Going:  right
# @104, 9, J	Going:  up
# @103, 9, |	Going:  up
# @102, 9, 7	Going:  left
# @102, 8, L	Going:  up
# @101, 8, 7	Going:  left
# @101, 7, L	Going:  up
# @100, 7, F	Going:  right
# @100, 8, J	Going:  up
# @99, 8, |	Going:  up
# @98, 8, F	Going:  right
# @98, 9, 7	Going:  down
# @99, 9, |	Going:  down
# @100, 9, |	Going:  down
# @101, 9, L	Going:  right
# @101, 10, 7	Going:  down
# @102, 10, |	Going:  down
# @103, 10, L	Going:  right
# @103, 11, J	Going:  up
# @102, 11, F	Going:  right
# @102, 12, 7	Going:  down
# @103, 12, |	Going:  down
# @104, 12, J	Going:  left
# @104, 11, -	Going:  left
# @104, 10, F	Going:  down
# @105, 10, L	Going:  right
# @105, 11, -	Going:  right
# @105, 12, 7	Going:  down
# @106, 12, L	Going:  right
# @106, 13, J	Going:  up
# @105, 13, |	Going:  up
# @104, 13, |	Going:  up
# @103, 13, F	Going:  right
# @103, 14, 7	Going:  down
# @104, 14, |	Going:  down
# @105, 14, |	Going:  down
# @106, 14, L	Going:  right
# @106, 15, J	Going:  up
# @105, 15, |	Going:  up
# @104, 15, |	Going:  up
# @103, 15, |	Going:  up
# @102, 15, F	Going:  right
# @102, 16, 7	Going:  down
# @103, 16, |	Going:  down
# @104, 16, |	Going:  down
# @105, 16, |	Going:  down
# @106, 16, L	Going:  right
# @106, 17, -	Going:  right
# @106, 18, J	Going:  up
# @105, 18, 7	Going:  left
# @105, 17, L	Going:  up
# @104, 17, F	Going:  right
# @104, 18, -	Going:  right
# @104, 19, 7	Going:  down
# @105, 19, |	Going:  down
# @106, 19, L	Going:  right
# @106, 20, J	Going:  up
# @105, 20, F	Going:  right
# @105, 21, 7	Going:  down
# @106, 21, L	Going:  right
# @106, 22, -	Going:  right
# @106, 23, J	Going:  up
# @105, 23, F	Going:  right
# @105, 24, 7	Going:  down
# @106, 24, L	Going:  right
# @106, 25, J	Going:  up
# @105, 25, |	Going:  up
# @104, 25, 7	Going:  left
# @104, 24, -	Going:  left
# @104, 23, -	Going:  left
# @104, 22, -	Going:  left
# @104, 21, -	Going:  left
# @104, 20, L	Going:  up
# @103, 20, F	Going:  right
# @103, 21, -	Going:  right
# @103, 22, -	Going:  right
# @103, 23, -	Going:  right
# @103, 24, -	Going:  right
# @103, 25, -	Going:  right
# @103, 26, 7	Going:  down
# @104, 26, |	Going:  down
# @105, 26, |	Going:  down
# @106, 26, L	Going:  right
# @106, 27, -	Going:  right
# @106, 28, -	Going:  right
# @106, 29, -	Going:  right
# @106, 30, J	Going:  up
# @105, 30, 7	Going:  left
# @105, 29, -	Going:  left
# @105, 28, -	Going:  left
# @105, 27, L	Going:  up
# @104, 27, |	Going:  up
# @103, 27, F	Going:  right
# @103, 28, 7	Going:  down
# @104, 28, L	Going:  right
# @104, 29, J	Going:  up
# @103, 29, F	Going:  right
# @103, 30, 7	Going:  down
# @104, 30, L	Going:  right
# @104, 31, J	Going:  up
# @103, 31, F	Going:  right
# @103, 32, 7	Going:  down
# @104, 32, L	Going:  right
# @104, 33, -	Going:  right
# @104, 34, -	Going:  right
# @104, 35, -	Going:  right
# @104, 36, J	Going:  up
# @103, 36, 7	Going:  left
# @103, 35, L	Going:  up
# @102, 35, 7	Going:  left
# @102, 34, F	Going:  down
# @103, 34, J	Going:  left
# @103, 33, L	Going:  up
# @102, 33, 7	Going:  left
# @102, 32, -	Going:  left
# @102, 31, -	Going:  left
# @102, 30, L	Going:  up
# @101, 30, F	Going:  right
# @101, 31, -	Going:  right
# @101, 32, J	Going:  up
# @100, 32, 7	Going:  left
# @100, 31, -	Going:  left
# @100, 30, -	Going:  left
# @100, 29, F	Going:  down
# @101, 29, |	Going:  down
# @102, 29, J	Going:  left
# @102, 28, -	Going:  left
# @102, 27, L	Going:  up
# @101, 27, F	Going:  right
# @101, 28, J	Going:  up
# @100, 28, 7	Going:  left
# @100, 27, -	Going:  left
# @100, 26, F	Going:  down
# @101, 26, |	Going:  down
# @102, 26, J	Going:  left
# @102, 25, L	Going:  up
# @101, 25, |	Going:  up
# @100, 25, |	Going:  up
# @99, 25, 7	Going:  left
# @99, 24, F	Going:  down
# @100, 24, |	Going:  down
# @101, 24, |	Going:  down
# @102, 24, J	Going:  left
# @102, 23, -	Going:  left
# @102, 22, -	Going:  left
# @102, 21, -	Going:  left
# @102, 20, -	Going:  left
# @102, 19, F	Going:  down
# @103, 19, J	Going:  left
# @103, 18, -	Going:  left
# @103, 17, L	Going:  up
# @102, 17, F	Going:  right
# @102, 18, J	Going:  up
# @101, 18, 7	Going:  left
# @101, 17, -	Going:  left
# @101, 16, L	Going:  up
# @100, 16, F	Going:  right
# @100, 17, -	Going:  right
# @100, 18, -	Going:  right
# @100, 19, 7	Going:  down
# @101, 19, L	Going:  right
# @101, 20, -	Going:  right
# @101, 21, -	Going:  right
# @101, 22, -	Going:  right
# @101, 23, J	Going:  up
# @100, 23, |	Going:  up
# @99, 23, 7	Going:  left
# @99, 22, -	Going:  left
# @99, 21, F	Going:  down
# @100, 21, J	Going:  left
# @100, 20, L	Going:  up
# @99, 20, 7	Going:  left
# @99, 19, -	Going:  left
# @99, 18, -	Going:  left
# @99, 17, -	Going:  left
# @99, 16, -	Going:  left
# @99, 15, F	Going:  down
# @100, 15, |	Going:  down
# @101, 15, J	Going:  left
# @101, 14, L	Going:  up
# @100, 14, |	Going:  up
# @99, 14, 7	Going:  left
# @99, 13, L	Going:  up
# @98, 13, F	Going:  right
# @98, 14, -	Going:  right
# @98, 15, -	Going:  right
# @98, 16, -	Going:  right
# @98, 17, -	Going:  right
# @98, 18, -	Going:  right
# @98, 19, -	Going:  right
# @98, 20, J	Going:  up
# @97, 20, 7	Going:  left
# @97, 19, -	Going:  left
# @97, 18, -	Going:  left
# @97, 17, L	Going:  up
# @96, 17, F	Going:  right
# @96, 18, -	Going:  right
# @96, 19, -	Going:  right
# @96, 20, -	Going:  right
# @96, 21, 7	Going:  down
# @97, 21, |	Going:  down
# @98, 21, L	Going:  right
# @98, 22, -	Going:  right
# @98, 23, J	Going:  up
# @97, 23, 7	Going:  left
# @97, 22, L	Going:  up
# @96, 22, F	Going:  right
# @96, 23, -	Going:  right
# @96, 24, 7	Going:  down
# @97, 24, |	Going:  down
# @98, 24, L	Going:  right
# @98, 25, J	Going:  up
# @97, 25, F	Going:  right
# @97, 26, 7	Going:  down
# @98, 26, |	Going:  down
# @99, 26, L	Going:  right
# @99, 27, -	Going:  right
# @99, 28, J	Going:  up
# @98, 28, 7	Going:  left
# @98, 27, L	Going:  up
# @97, 27, F	Going:  right
# @97, 28, -	Going:  right
# @97, 29, 7	Going:  down
# @98, 29, |	Going:  down
# @99, 29, L	Going:  right
# @99, 30, J	Going:  up
# @98, 30, F	Going:  right
# @98, 31, 7	Going:  down
# @99, 31, L	Going:  right
# @99, 32, -	Going:  right
# @99, 33, 7	Going:  down
# @100, 33, |	Going:  down
# @101, 33, L	Going:  right
# @101, 34, -	Going:  right
# @101, 35, -	Going:  right
# @101, 36, -	Going:  right
# @101, 37, -	Going:  right
# @101, 38, J	Going:  up
# @100, 38, 7	Going:  left
# @100, 37, -	Going:  left
# @100, 36, -	Going:  left
# @100, 35, -	Going:  left
# @100, 34, L	Going:  up
# @99, 34, F	Going:  right
# @99, 35, -	Going:  right
# @99, 36, J	Going:  up
# @98, 36, 7	Going:  left
# @98, 35, -	Going:  left
# @98, 34, L	Going:  up
# @97, 34, F	Going:  right
# @97, 35, -	Going:  right
# @97, 36, -	Going:  right
# @97, 37, 7	Going:  down
# @98, 37, |	Going:  down
# @99, 37, L	Going:  right
# @99, 38, J	Going:  up
# @98, 38, F	Going:  right
# @98, 39, -	Going:  right
# @98, 40, 7	Going:  down
# @99, 40, J	Going:  left
# @99, 39, F	Going:  down
# @100, 39, L	Going:  right
# @100, 40, -	Going:  right
# @100, 41, J	Going:  up
# @99, 41, F	Going:  right
# @99, 42, J	Going:  up
# @98, 42, 7	Going:  left
# @98, 41, L	Going:  up
# @97, 41, 7	Going:  left
# @97, 40, -	Going:  left
# @97, 39, -	Going:  left
# @97, 38, L	Going:  up
# @96, 38, F	Going:  right
# @96, 39, -	Going:  right
# @96, 40, -	Going:  right
# @96, 41, -	Going:  right
# @96, 42, 7	Going:  down
# @97, 42, L	Going:  right
# @97, 43, J	Going:  up
# @96, 43, F	Going:  right
# @96, 44, J	Going:  up
# @95, 44, 7	Going:  left
# @95, 43, L	Going:  up
# @94, 43, F	Going:  right
# @94, 44, -	Going:  right
# @94, 45, J	Going:  up
# @93, 45, 7	Going:  left
# @93, 44, -	Going:  left
# @93, 43, -	Going:  left
# @93, 42, -	Going:  left
# @93, 41, F	Going:  down
# @94, 41, L	Going:  right
# @94, 42, 7	Going:  down
# @95, 42, J	Going:  left
# @95, 41, -	Going:  left
# @95, 40, L	Going:  up
# @94, 40, 7	Going:  left
# @94, 39, F	Going:  down
# @95, 39, J	Going:  left
# @95, 38, L	Going:  up
# @94, 38, 7	Going:  left
# @94, 37, F	Going:  down
# @95, 37, |	Going:  down
# @96, 37, J	Going:  left
# @96, 36, -	Going:  left
# @96, 35, L	Going:  up
# @95, 35, F	Going:  right
# @95, 36, J	Going:  up
# @94, 36, 7	Going:  left
# @94, 35, -	Going:  left
# @94, 34, F	Going:  down
# @95, 34, |	Going:  down
# @96, 34, J	Going:  left
# @96, 33, F	Going:  down
# @97, 33, |	Going:  down
# @98, 33, J	Going:  left
# @98, 32, L	Going:  up
# @97, 32, 7	Going:  left
# @97, 31, -	Going:  left
# @97, 30, L	Going:  up
# @96, 30, F	Going:  right
# @96, 31, -	Going:  right
# @96, 32, J	Going:  up
# @95, 32, F	Going:  right
# @95, 33, J	Going:  up
# @94, 33, 7	Going:  left
# @94, 32, -	Going:  left
# @94, 31, F	Going:  down
# @95, 31, J	Going:  left
# @95, 30, L	Going:  up
# @94, 30, 7	Going:  left
# @94, 29, F	Going:  down
# @95, 29, |	Going:  down
# @96, 29, J	Going:  left
# @96, 28, -	Going:  left
# @96, 27, -	Going:  left
# @96, 26, L	Going:  up
# @95, 26, F	Going:  right
# @95, 27, -	Going:  right
# @95, 28, J	Going:  up
# @94, 28, 7	Going:  left
# @94, 27, -	Going:  left
# @94, 26, -	Going:  left
# @94, 25, F	Going:  down
# @95, 25, J	Going:  left
# @95, 24, -	Going:  left
# @95, 23, -	Going:  left
# @95, 22, -	Going:  left
# @95, 21, -	Going:  left
# @95, 20, -	Going:  left
# @95, 19, -	Going:  left
# @95, 18, -	Going:  left
# @95, 17, -	Going:  left
# @95, 16, F	Going:  down
# @96, 16, |	Going:  down
# @97, 16, J	Going:  left
# @97, 15, L	Going:  up
# @96, 15, |	Going:  up
# @95, 15, |	Going:  up
# @94, 15, F	Going:  right
# @94, 16, -	Going:  right
# @94, 17, -	Going:  right
# @94, 18, -	Going:  right
# @94, 19, -	Going:  right
# @94, 20, -	Going:  right
# @94, 21, -	Going:  right
# @94, 22, -	Going:  right
# @94, 23, -	Going:  right
# @94, 24, J	Going:  up
# @93, 24, 7	Going:  left
# @93, 23, -	Going:  left
# @93, 22, -	Going:  left
# @93, 21, -	Going:  left
# @93, 20, -	Going:  left
# @93, 19, -	Going:  left
# @93, 18, -	Going:  left
# @93, 17, -	Going:  left
# @93, 16, -	Going:  left
# @93, 15, L	Going:  up
# @92, 15, 7	Going:  left
# @92, 14, F	Going:  down
# @93, 14, |	Going:  down
# @94, 14, |	Going:  down
# @95, 14, |	Going:  down
# @96, 14, |	Going:  down
# @97, 14, J	Going:  left
# @97, 13, L	Going:  up
# @96, 13, 7	Going:  left
# @96, 12, L	Going:  up
# @95, 12, F	Going:  right
# @95, 13, J	Going:  up
# @94, 13, |	Going:  up
# @93, 13, 7	Going:  left
# @93, 12, -	Going:  left
# @93, 11, L	Going:  up
# @92, 11, |	Going:  up
# @91, 11, 7	Going:  left
# @91, 10, L	Going:  up
# @90, 10, |	Going:  up
# @89, 10, F	Going:  right
# @89, 11, 7	Going:  down
# @90, 11, L	Going:  right
# @90, 12, 7	Going:  down
# @91, 12, |	Going:  down
# @92, 12, L	Going:  right
# @92, 13, J	Going:  up
# @91, 13, F	Going:  right
# @91, 14, -	Going:  right
# @91, 15, -	Going:  right
# @89, 33, F	Going:  right
# @89, 34, 7	Going:  down
# @90, 34, |	Going:  down
# @91, 34, L	Going:  right
# @91, 35, -	Going:  right
# @91, 36, -	Going:  right
# @91, 37, -	Going:  right
# @91, 38, -	Going:  right
# @91, 39, -	Going:  right
# @91, 40, J	Going:  up
# @90, 40, F	Going:  right
# @90, 41, 7	Going:  down
# @91, 41, |	Going:  down
# @92, 41, L	Going:  right
# @92, 42, -	Going:  right
# @92, 43, -	Going:  right
# @92, 44, -	Going:  right
# @92, 45, J	Going:  up
# @91, 45, 7	Going:  left
# @91, 44, -	Going:  left
# @91, 43, -	Going:  left
# @91, 42, L	Going:  up
# @90, 42, F	Going:  right
# @90, 43, -	Going:  right
# @90, 44, -	Going:  right
# @90, 45, -	Going:  right
# @90, 46, J	Going:  up
# @89, 46, 7	Going:  left
# @89, 45, -	Going:  left
# @89, 44, L	Going:  up
# @88, 44, F	Going:  right
# @88, 45, -	Going:  right
# @88, 46, -	Going:  right
# @88, 47, -	Going:  right
# @88, 48, -	Going:  right
# @88, 49, J	Going:  up
# @87, 49, 7	Going:  left
# @87, 48, L	Going:  up
# @86, 48, 7	Going:  left
# @86, 47, F	Going:  down
# @87, 47, J	Going:  left
# @87, 46, -	Going:  left
# @87, 45, -	Going:  left
# @87, 44, L	Going:  up
# @86, 44, F	Going:  right
# @86, 45, -	Going:  right
# @86, 46, J	Going:  up
# @85, 46, 7	Going:  left
# @85, 45, -	Going:  left
# @85, 44, -	Going:  left
# @85, 43, F	Going:  down
# @86, 43, |	Going:  down
# @87, 43, |	Going:  down
# @88, 43, |	Going:  down
# @89, 43, J	Going:  left
# @89, 42, L	Going:  up
# @88, 42, |	Going:  up
# @87, 42, |	Going:  up
# @86, 42, |	Going:  up
# @85, 42, 7	Going:  left
# @85, 41, F	Going:  down
# @86, 41, |	Going:  down
# @87, 41, |	Going:  down
# @88, 41, |	Going:  down
# @89, 41, J	Going:  left
# @89, 40, -	Going:  left
# @89, 39, F	Going:  down
# @90, 39, J	Going:  left
# @90, 38, -	Going:  left
# @90, 37, -	Going:  left
# @90, 36, -	Going:  left
# @90, 35, L	Going:  up
# @89, 35, F	Going:  right
# @89, 36, J	Going:  up
# @88, 36, 7	Going:  left
# @88, 35, -	Going:  left
# @88, 34, -	Going:  left
# @88, 33, L	Going:  up
# @87, 33, F	Going:  right
# @87, 34, -	Going:  right
# @87, 35, -	Going:  right
# @87, 36, -	Going:  right
# @87, 37, 7	Going:  down
# @88, 37, |	Going:  down
# @89, 37, L	Going:  right
# @89, 38, J	Going:  up
# @88, 38, F	Going:  right
# @88, 39, -	Going:  right
# @88, 40, J	Going:  up
# @87, 40, |	Going:  up
# @86, 40, 7	Going:  left
# @86, 39, F	Going:  down
# @87, 39, J	Going:  left
# @87, 38, L	Going:  up
# @86, 38, 7	Going:  left
# @86, 37, -	Going:  left
# @86, 36, -	Going:  left
# @86, 35, L	Going:  up
# @85, 35, 7	Going:  left
# @85, 34, F	Going:  down
# @86, 34, J	Going:  left
# @82, 35, F	Going:  right
# @82, 36, -	Going:  right
# @82, 37, -	Going:  right
# @82, 38, -	Going:  right
# @82, 39, -	Going:  right
# @82, 40, -	Going:  right
# @82, 41, J	Going:  up
# @81, 41, |	Going:  up
# @80, 41, 7	Going:  left
# @80, 40, F	Going:  down
# @81, 40, J	Going:  left
# @81, 39, L	Going:  up
# @80, 39, 7	Going:  left
# @80, 38, F	Going:  down
# @81, 38, J	Going:  left
# @81, 37, -	Going:  left
# @81, 36, -	Going:  left
# @81, 35, -	Going:  left
# @81, 34, F	Going:  down
# @82, 34, |	Going:  down
# @83, 34, J	Going:  left
# @83, 33, L	Going:  up
# @82, 33, 7	Going:  left
# @82, 32, F	Going:  down
# @83, 32, J	Going:  left
# @83, 31, -	Going:  left
# @83, 30, L	Going:  up
# @82, 30, F	Going:  right
# @82, 31, J	Going:  up
# @81, 31, F	Going:  right
# @81, 32, -	Going:  right
# @81, 33, J	Going:  up
# @80, 33, 7	Going:  left
# @80, 32, -	Going:  left
# @80, 31, L	Going:  up
# @79, 31, 7	Going:  left
# @79, 30, F	Going:  down
# @80, 30, |	Going:  down
# @81, 30, J	Going:  left
# @81, 29, L	Going:  up
# @80, 29, |	Going:  up
# @79, 29, 7	Going:  left
# @79, 28, F	Going:  down
# @80, 28, |	Going:  down
# @81, 28, J	Going:  left
# @81, 27, L	Going:  up
# @80, 27, 7	Going:  left
# @80, 26, F	Going:  down
# @81, 26, J	Going:  left
# @81, 25, L	Going:  up
# @80, 25, 7	Going:  left
# @80, 24, F	Going:  down
# @81, 24, J	Going:  left
# @81, 23, L	Going:  up
# @80, 23, 7	Going:  left
# @80, 22, L	Going:  up
# @79, 22, 7	Going:  left
# @79, 21, L	Going:  up
# @78, 21, F	Going:  right
# @78, 22, -	Going:  right
# @78, 23, 7	Going:  down
# @79, 23, L	Going:  right
# @79, 24, J	Going:  up
# @78, 24, F	Going:  right
# @78, 25, 7	Going:  down
# @79, 25, L	Going:  right
# @79, 26, -	Going:  right
# @79, 27, J	Going:  up
# @78, 27, 7	Going:  left
# @78, 26, L	Going:  up
# @77, 26, F	Going:  right
# @77, 27, -	Going:  right
# @77, 28, 7	Going:  down
# @78, 28, L	Going:  right
# @78, 29, J	Going:  up
# @77, 29, |	Going:  up
# @76, 29, F	Going:  right
# @76, 30, 7	Going:  down
# @77, 30, |	Going:  down
# @78, 30, L	Going:  right
# @78, 31, -	Going:  right
# @78, 32, 7	Going:  down
# @79, 32, L	Going:  right
# @79, 33, -	Going:  right
# @79, 34, 7	Going:  down
# @80, 34, L	Going:  right
# @80, 35, -	Going:  right
# @80, 36, -	Going:  right
# @80, 37, J	Going:  up
# @79, 37, F	Going:  right
# @79, 38, J	Going:  up
# @78, 38, F	Going:  right
# @78, 39, 7	Going:  down
# @79, 39, L	Going:  right
# @79, 40, -	Going:  right
# @79, 41, J	Going:  up
# @78, 41, 7	Going:  left
# @78, 40, L	Going:  up
# @77, 40, 7	Going:  left
# @77, 39, -	Going:  left
# @77, 38, L	Going:  up
# @76, 38, 7	Going:  left
# @76, 37, F	Going:  down
# @77, 37, |	Going:  down
# @78, 37, J	Going:  left
# @78, 36, F	Going:  down
# @79, 36, J	Going:  left
# @79, 35, L	Going:  up
# @78, 35, 7	Going:  left
# @78, 34, -	Going:  left
# @78, 33, L	Going:  up
# @77, 33, F	Going:  right
# @77, 34, -	Going:  right
# @77, 35, -	Going:  right
# @77, 36, J	Going:  up
# @76, 36, 7	Going:  left
# @76, 35, L	Going:  up
# @75, 35, |	Going:  up
# @74, 35, F	Going:  right
# @74, 36, 7	Going:  down
# @75, 36, L	Going:  right
# @75, 37, J	Going:  up
# @74, 37, F	Going:  right
# @74, 38, 7	Going:  down
# @75, 38, L	Going:  right
# @75, 39, J	Going:  up
# @74, 39, F	Going:  right
# @74, 40, 7	Going:  down
# @75, 40, |	Going:  down
# @76, 40, L	Going:  right
# @76, 41, 7	Going:  down
# @77, 41, L	Going:  right
# @77, 42, -	Going:  right
# @77, 43, 7	Going:  down
# @78, 43, |	Going:  down
# @79, 43, J	Going:  left
# @79, 42, F	Going:  down
# @80, 42, L	Going:  right
# @80, 43, 7	Going:  down
# @81, 43, J	Going:  left
# @81, 42, F	Going:  down
# @82, 42, L	Going:  right
# @82, 43, -	Going:  right
# @82, 44, J	Going:  up
# @81, 44, |	Going:  up
# @80, 44, |	Going:  up
# @79, 44, |	Going:  up
# @78, 44, F	Going:  right
# @78, 45, 7	Going:  down
# @79, 45, |	Going:  down
# @80, 45, |	Going:  down
# @81, 45, |	Going:  down
# @82, 45, |	Going:  down
# @83, 45, J	Going:  left
# @83, 44, -	Going:  left
# @83, 43, F	Going:  down
# @84, 43, L	Going:  right
# @84, 44, -	Going:  right
# @84, 45, -	Going:  right
# @84, 46, J	Going:  up
# @83, 46, |	Going:  up
# @82, 46, |	Going:  up
# @81, 46, |	Going:  up
# @80, 46, F	Going:  right
# @80, 47, 7	Going:  down
# @81, 47, |	Going:  down
# @82, 47, |	Going:  down
# @83, 47, |	Going:  down
# @84, 47, |	Going:  down
# @85, 47, L	Going:  right
# @85, 48, J	Going:  up
# @84, 48, F	Going:  right
# @84, 49, J	Going:  up
# @83, 49, 7	Going:  left
# @83, 48, L	Going:  up
# @82, 48, F	Going:  right
# @82, 49, J	Going:  up
# @81, 49, 7	Going:  left
# @81, 48, L	Going:  up
# @80, 48, F	Going:  right
# @80, 49, -	Going:  right
# @80, 50, 7	Going:  down
# @81, 50, L	Going:  right
# @81, 51, J	Going:  up
# @80, 51, F	Going:  right
# @80, 52, 7	Going:  down
# @81, 52, |	Going:  down
# @82, 52, J	Going:  left
# @82, 51, -	Going:  left
# @82, 50, F	Going:  down
# @83, 50, L	Going:  right
# @83, 51, -	Going:  right
# @83, 52, 7	Going:  down
# @84, 52, J	Going:  left
# @84, 51, F	Going:  down
# @85, 51, J	Going:  left
# @85, 50, -	Going:  left
# @85, 49, F	Going:  down
# @86, 49, L	Going:  right
# @86, 50, -	Going:  right
# @86, 51, -	Going:  right
# @86, 52, J	Going:  up
# @85, 52, F	Going:  right
# @85, 53, 7	Going:  down
# @86, 53, |	Going:  down
# @87, 53, L	Going:  right
# @87, 54, -	Going:  right
# @87, 55, -	Going:  right
# @87, 56, -	Going:  right
# @87, 57, J	Going:  up
# @86, 57, 7	Going:  left
# @86, 56, -	Going:  left
# @86, 55, -	Going:  left
# @86, 54, L	Going:  up
# @85, 54, |	Going:  up
# @84, 54, 7	Going:  left
# @84, 53, L	Going:  up
# @83, 53, |	Going:  up
# @82, 53, |	Going:  up
# @81, 53, |	Going:  up
# @80, 53, F	Going:  right
# @80, 54, 7	Going:  down
# @81, 54, |	Going:  down
# @82, 54, |	Going:  down
# @83, 54, L	Going:  right
# @83, 55, 7	Going:  down
# @84, 55, L	Going:  right
# @84, 56, 7	Going:  down
# @85, 56, L	Going:  right
# @85, 57, J	Going:  up
# @84, 57, F	Going:  right
# @84, 58, J	Going:  up
# @83, 58, 7	Going:  left
# @83, 57, -	Going:  left
# @83, 56, L	Going:  up
# @82, 56, 7	Going:  left
# @82, 55, L	Going:  up
# @81, 55, F	Going:  right
# @81, 56, -	Going:  right
# @81, 57, 7	Going:  down
# @82, 57, L	Going:  right
# @82, 58, -	Going:  right
# @82, 59, -	Going:  right
# @82, 60, 7	Going:  down
# @83, 60, J	Going:  left
# @83, 59, F	Going:  down
# @84, 59, |	Going:  down
# @85, 59, L	Going:  right
# @85, 60, J	Going:  up
# @84, 60, F	Going:  right
# @84, 61, J	Going:  up
# @83, 61, |	Going:  up
# @82, 61, F	Going:  right
# @82, 62, 7	Going:  down
# @83, 62, L	Going:  right
# @83, 63, J	Going:  up
# @82, 63, F	Going:  right
# @82, 64, J	Going:  up
# @81, 64, 7	Going:  left
# @81, 63, L	Going:  up
# @80, 63, |	Going:  up
# @79, 63, |	Going:  up
# @78, 63, |	Going:  up
# @77, 63, 7	Going:  left
# @77, 62, -	Going:  left
# @77, 61, -	Going:  left
# @77, 60, F	Going:  down
# @78, 60, L	Going:  right
# @78, 61, -	Going:  right
# @78, 62, 7	Going:  down
# @79, 62, |	Going:  down
# @80, 62, |	Going:  down
# @81, 62, J	Going:  left
# @81, 61, L	Going:  up
# @80, 61, |	Going:  up
# @79, 61, 7	Going:  left
# @79, 60, F	Going:  down
# @80, 60, |	Going:  down
# @81, 60, J	Going:  left
# @81, 59, -	Going:  left
# @81, 58, L	Going:  up
# @80, 58, F	Going:  right
# @80, 59, J	Going:  up
# @79, 59, 7	Going:  left
# @79, 58, L	Going:  up
# @78, 58, 7	Going:  left
# @78, 57, -	Going:  left
# @78, 56, F	Going:  down
# @79, 56, L	Going:  right
# @79, 57, 7	Going:  down
# @80, 57, J	Going:  left
# @80, 56, -	Going:  left
# @80, 55, L	Going:  up
# @79, 55, 7	Going:  left
# @79, 54, L	Going:  up
# @78, 54, 7	Going:  left
# @78, 53, F	Going:  down
# @79, 53, J	Going:  left
# @79, 52, L	Going:  up
# @78, 52, 7	Going:  left
# @78, 51, F	Going:  down
# @79, 51, J	Going:  left
# @79, 50, L	Going:  up
# @78, 50, 7	Going:  left
# @78, 49, F	Going:  down
# @79, 49, J	Going:  left
# @79, 48, L	Going:  up
# @78, 48, 7	Going:  left
# @78, 47, F	Going:  down
# @79, 47, J	Going:  left
# @79, 46, L	Going:  up
# @78, 46, |	Going:  up
# @77, 46, F	Going:  right
# @77, 47, -	Going:  right
# @77, 48, -	Going:  right
# @77, 49, -	Going:  right
# @77, 50, -	Going:  right
# @77, 51, -	Going:  right
# @77, 52, -	Going:  right
# @77, 53, -	Going:  right
# @77, 54, -	Going:  right
# @77, 55, -	Going:  right
# @77, 56, -	Going:  right
# @77, 57, -	Going:  right
# @77, 58, -	Going:  right
# @77, 59, J	Going:  up
# @76, 59, F	Going:  right
# @76, 60, J	Going:  up
# @75, 60, F	Going:  right
# @75, 61, 7	Going:  down
# @76, 61, L	Going:  right
# @76, 62, J	Going:  up
# @75, 62, F	Going:  right
# @75, 63, -	Going:  right
# @75, 64, 7	Going:  down
# @76, 64, |	Going:  down
# @77, 64, L	Going:  right
# @77, 65, J	Going:  up
# @76, 65, |	Going:  up
# @75, 65, |	Going:  up
# @74, 65, |	Going:  up
# @73, 65, F	Going:  right
# @73, 66, 7	Going:  down
# @74, 66, L	Going:  right
# @74, 67, J	Going:  up
# @73, 67, F	Going:  right
# @73, 68, J	Going:  up
# @72, 68, 7	Going:  left
# @72, 67, -	Going:  left
# @72, 66, L	Going:  up
# @71, 66, 7	Going:  left
# @71, 65, F	Going:  down
# @72, 65, J	Going:  left
# @72, 64, F	Going:  down
# @73, 64, |	Going:  down
# @74, 64, J	Going:  left
# @74, 63, -	Going:  left
# @74, 62, L	Going:  up
# @73, 62, F	Going:  right
# @73, 63, J	Going:  up
# @72, 63, |	Going:  up
# @71, 63, 7	Going:  left
# @71, 62, F	Going:  down
# @72, 62, J	Going:  left
# @72, 61, F	Going:  down
# @73, 61, |	Going:  down
# @74, 61, J	Going:  left
# @74, 60, L	Going:  up
# @73, 60, 7	Going:  left
# @73, 59, F	Going:  down
# @74, 59, |	Going:  down
# @75, 59, J	Going:  left
# @75, 58, F	Going:  down
# @76, 58, J	Going:  left
# @76, 57, L	Going:  up
# @75, 57, 7	Going:  left
# @75, 56, F	Going:  down
# @76, 56, J	Going:  left
# @76, 55, -	Going:  left
# @76, 54, L	Going:  up
# @75, 54, F	Going:  right
# @75, 55, J	Going:  up
# @74, 55, F	Going:  right
# @74, 56, J	Going:  up
# @73, 56, 7	Going:  left
# @73, 55, L	Going:  up
# @72, 55, F	Going:  right
# @72, 56, -	Going:  right
# @72, 57, 7	Going:  down
# @73, 57, |	Going:  down
# @74, 57, L	Going:  right
# @74, 58, J	Going:  up
# @73, 58, |	Going:  up
# @72, 58, F	Going:  right
# @72, 59, -	Going:  right
# @72, 60, J	Going:  up
# @71, 60, 7	Going:  left
# @71, 59, -	Going:  left
# @71, 58, L	Going:  up
# @70, 58, 7	Going:  left
# @70, 57, F	Going:  down
# @71, 57, J	Going:  left
# @71, 56, L	Going:  up
# @70, 56, |	Going:  up
# @69, 56, F	Going:  right
# @69, 57, -	Going:  right
# @69, 58, -	Going:  right
# @69, 59, 7	Going:  down
# @70, 59, L	Going:  right
# @70, 60, J	Going:  up
# @69, 60, F	Going:  right
# @69, 61, -	Going:  right
# @69, 62, J	Going:  up
# @68, 62, 7	Going:  left
# @68, 61, L	Going:  up
# @67, 61, 7	Going:  left
# @67, 60, F	Going:  down
# @68, 60, J	Going:  left
# @68, 59, L	Going:  up
# @67, 59, |	Going:  up
# @66, 59, 7	Going:  left
# @66, 58, F	Going:  down
# @67, 58, |	Going:  down
# @68, 58, J	Going:  left
# @68, 57, L	Going:  up
# @67, 57, 7	Going:  left
# @67, 56, F	Going:  down
# @68, 56, J	Going:  left
# @68, 55, -	Going:  left
# @68, 54, F	Going:  down
# @69, 54, L	Going:  right
# @69, 55, 7	Going:  down
# @70, 55, |	Going:  down
# @71, 55, J	Going:  left
# @71, 54, F	Going:  down
# @72, 54, |	Going:  down
# @73, 54, |	Going:  down
# @74, 54, J	Going:  left
# @74, 53, F	Going:  down
# @75, 53, |	Going:  down
# @76, 53, J	Going:  left
# @76, 52, L	Going:  up
# @75, 52, |	Going:  up
# @74, 52, 7	Going:  left
# @74, 51, F	Going:  down
# @75, 51, |	Going:  down
# @76, 51, J	Going:  left
# @76, 50, -	Going:  left
# @76, 49, -	Going:  left
# @76, 48, -	Going:  left
# @76, 47, -	Going:  left
# @76, 46, -	Going:  left
# @76, 45, F	Going:  down
# @77, 45, J	Going:  left
# @77, 44, L	Going:  up
# @76, 44, 7	Going:  left
# @76, 43, -	Going:  left
# @76, 42, L	Going:  up
# @75, 42, 7	Going:  left
# @75, 41, L	Going:  up
# @74, 41, F	Going:  right
# @74, 42, -	Going:  right
# @74, 43, 7	Going:  down
# @75, 43, L	Going:  right
# @75, 44, -	Going:  right
# @75, 45, -	Going:  right
# @75, 46, -	Going:  right
# @75, 47, -	Going:  right
# @75, 48, -	Going:  right
# @75, 49, -	Going:  right
# @75, 50, J	Going:  up
# @74, 50, 7	Going:  left
# @74, 49, -	Going:  left
# @74, 48, L	Going:  up
# @73, 48, F	Going:  right
# @73, 49, -	Going:  right
# @73, 50, -	Going:  right
# @73, 51, -	Going:  right
# @73, 52, -	Going:  right
# @73, 53, J	Going:  up
# @72, 53, 7	Going:  left
# @72, 52, -	Going:  left
# @72, 51, -	Going:  left
# @72, 50, -	Going:  left
# @72, 49, -	Going:  left
# @72, 48, -	Going:  left
# @72, 47, F	Going:  down
# @73, 47, |	Going:  down
# @74, 47, J	Going:  left
# @74, 46, L	Going:  up
# @73, 46, 7	Going:  left
# @73, 45, F	Going:  down
# @74, 45, J	Going:  left
# @74, 44, L	Going:  up
# @73, 44, 7	Going:  left
# @73, 43, L	Going:  up
# @72, 43, F	Going:  right
# @72, 44, -	Going:  right
# @72, 45, J	Going:  up
# @71, 45, 7	Going:  left
# @71, 44, -	Going:  left
# @71, 43, L	Going:  up
# @70, 43, F	Going:  right
# @70, 44, -	Going:  right
# @70, 45, -	Going:  right
# @70, 46, 7	Going:  down
# @71, 46, L	Going:  right
# @71, 47, -	Going:  right
# @71, 48, -	Going:  right
# @71, 49, -	Going:  right
# @71, 50, -	Going:  right
# @71, 51, -	Going:  right
# @71, 52, -	Going:  right
# @71, 53, J	Going:  up
# @70, 53, 7	Going:  left
# @70, 52, L	Going:  up
# @69, 52, F	Going:  right
# @69, 53, J	Going:  up
# @68, 53, 7	Going:  left
# @68, 52, -	Going:  left
# @68, 51, F	Going:  down
# @69, 51, |	Going:  down
# @70, 51, J	Going:  left
# @70, 50, -	Going:  left
# @70, 49, L	Going:  up
# @69, 49, F	Going:  right
# @69, 50, J	Going:  up
# @68, 50, 7	Going:  left
# @68, 49, -	Going:  left
# @68, 48, F	Going:  down
# @69, 48, |	Going:  down
# @70, 48, J	Going:  left
# @70, 47, L	Going:  up
# @69, 47, 7	Going:  left
# @69, 46, -	Going:  left
# @69, 45, -	Going:  left
# @69, 44, -	Going:  left
# @69, 43, L	Going:  up
# @68, 43, F	Going:  right
# @68, 44, -	Going:  right
# @68, 45, -	Going:  right
# @68, 46, -	Going:  right
# @68, 47, J	Going:  up
# @67, 47, 7	Going:  left
# @67, 46, -	Going:  left
# @67, 45, L	Going:  up
# @66, 45, F	Going:  right
# @66, 46, J	Going:  up
# @65, 46, F	Going:  right
# @65, 47, -	Going:  right
# @65, 48, 7	Going:  down
# @66, 48, |	Going:  down
# @67, 48, L	Going:  right
# @67, 49, -	Going:  right
# @67, 50, -	Going:  right
# @67, 51, -	Going:  right
# @67, 52, J	Going:  up
# @66, 52, 7	Going:  left
# @66, 51, -	Going:  left
# @66, 50, -	Going:  left
# @66, 49, L	Going:  up
# @65, 49, F	Going:  right
# @65, 50, -	Going:  right
# @65, 51, -	Going:  right
# @65, 52, -	Going:  right
# @65, 53, 7	Going:  down
# @66, 53, |	Going:  down
# @67, 53, L	Going:  right
# @67, 54, -	Going:  right
# @67, 55, J	Going:  up
# @66, 55, 7	Going:  left
# @66, 54, L	Going:  up
# @65, 54, F	Going:  right
# @65, 55, -	Going:  right
# @65, 56, 7	Going:  down
# @66, 56, L	Going:  right
# @66, 57, J	Going:  up
# @65, 57, F	Going:  right
# @65, 58, -	Going:  right
# @65, 59, -	Going:  right
# @65, 60, J	Going:  up
# @64, 60, 7	Going:  left
# @64, 59, -	Going:  left
# @64, 58, -	Going:  left
# @64, 57, -	Going:  left
# @64, 56, L	Going:  up
# @63, 56, F	Going:  right
# @63, 57, -	Going:  right
# @63, 58, -	Going:  right
# @63, 59, -	Going:  right
# @63, 60, -	Going:  right
# @63, 61, 7	Going:  down
# @64, 61, |	Going:  down
# @65, 61, |	Going:  down
# @66, 61, L	Going:  right
# @66, 62, 7	Going:  down
# @67, 62, L	Going:  right
# @67, 63, J	Going:  up
# @66, 63, F	Going:  right
# @66, 64, 7	Going:  down
# @67, 64, L	Going:  right
# @67, 65, J	Going:  up
# @66, 65, F	Going:  right
# @66, 66, 7	Going:  down
# @67, 66, L	Going:  right
# @67, 67, J	Going:  up
# @66, 67, F	Going:  right
# @66, 68, -	Going:  right
# @66, 69, J	Going:  up
# @65, 69, 7	Going:  left
# @65, 68, -	Going:  left
# @65, 67, -	Going:  left
# @65, 66, -	Going:  left
# @65, 65, -	Going:  left
# @65, 64, -	Going:  left
# @65, 63, -	Going:  left
# @65, 62, L	Going:  up
# @64, 62, |	Going:  up
# @63, 62, F	Going:  right
# @63, 63, 7	Going:  down
# @64, 63, L	Going:  right
# @64, 64, -	Going:  right
# @64, 65, -	Going:  right
# @64, 66, -	Going:  right
# @64, 67, -	Going:  right
# @64, 68, J	Going:  up
# @63, 68, 7	Going:  left
# @63, 67, -	Going:  left
# @63, 66, -	Going:  left
# @63, 65, -	Going:  left
# @63, 64, L	Going:  up
# @62, 64, 7	Going:  left
# @62, 63, -	Going:  left
# @62, 62, L	Going:  up
# @61, 62, |	Going:  up
# @60, 62, F	Going:  right
# @60, 63, 7	Going:  down
# @61, 63, L	Going:  right
# @61, 64, -	Going:  right
# @61, 65, J	Going:  up
# @60, 65, 7	Going:  left
# @60, 64, L	Going:  up
# @59, 64, 7	Going:  left
# @59, 63, -	Going:  left
# @59, 62, L	Going:  up
# @58, 62, F	Going:  right
# @58, 63, -	Going:  right
# @58, 64, J	Going:  up
# @57, 64, 7	Going:  left
# @57, 63, -	Going:  left
# @57, 62, -	Going:  left
# @57, 61, F	Going:  down
# @58, 61, J	Going:  left
# @58, 60, F	Going:  down
# @59, 60, L	Going:  right
# @59, 61, 7	Going:  down
# @60, 61, J	Going:  left
# @60, 60, F	Going:  down
# @61, 60, L	Going:  right
# @61, 61, 7	Going:  down
# @62, 61, J	Going:  left
# @62, 60, -	Going:  left
# @62, 59, -	Going:  left
# @62, 58, -	Going:  left
# @62, 57, L	Going:  up
# @61, 57, F	Going:  right
# @61, 58, -	Going:  right
# @61, 59, J	Going:  up
# @60, 59, 7	Going:  left
# @60, 58, -	Going:  left
# @60, 57, -	Going:  left
# @60, 56, F	Going:  down
# @61, 56, |	Going:  down
# @62, 56, J	Going:  left
# @62, 55, F	Going:  down
# @63, 55, |	Going:  down
# @64, 55, J	Going:  left
# @64, 54, L	Going:  up
# @63, 54, 7	Going:  left
# @63, 53, F	Going:  down
# @64, 53, J	Going:  left
# @64, 52, L	Going:  up
# @63, 52, 7	Going:  left
# @63, 51, F	Going:  down
# @64, 51, J	Going:  left
# @64, 50, -	Going:  left
# @64, 49, L	Going:  up
# @63, 49, F	Going:  right
# @63, 50, J	Going:  up
# @62, 50, F	Going:  right
# @62, 51, -	Going:  right
# @62, 52, -	Going:  right
# @62, 53, -	Going:  right
# @62, 54, J	Going:  up
# @61, 54, 7	Going:  left
# @61, 53, -	Going:  left
# @61, 52, L	Going:  up
# @60, 52, 7	Going:  left
# @60, 51, F	Going:  down
# @61, 51, J	Going:  left
# @61, 50, L	Going:  up
# @60, 50, 7	Going:  left
# @60, 49, -	Going:  left
# @60, 48, F	Going:  down
# @61, 48, L	Going:  right
# @61, 49, 7	Going:  down
# @62, 49, J	Going:  left
# @62, 48, F	Going:  down
# @63, 48, |	Going:  down
# @64, 48, J	Going:  left
# @64, 47, L	Going:  up
# @63, 47, |	Going:  up
# @62, 47, 7	Going:  left
# @62, 46, F	Going:  down
# @63, 46, |	Going:  down
# @64, 46, J	Going:  left
# @64, 45, F	Going:  down
# @65, 45, J	Going:  left
# @65, 44, -	Going:  left
# @65, 43, F	Going:  down
# @66, 43, L	Going:  right
# @66, 44, 7	Going:  down
# @67, 44, J	Going:  left
# @67, 43, -	Going:  left
# @67, 42, F	Going:  down
# @68, 42, |	Going:  down
# @69, 42, |	Going:  down
# @70, 42, |	Going:  down
# @71, 42, J	Going:  left
# @71, 41, -	Going:  left
# @71, 40, F	Going:  down
# @72, 40, L	Going:  right
# @72, 41, -	Going:  right
# @72, 42, 7	Going:  down
# @73, 42, J	Going:  left
# @73, 41, -	Going:  left
# @73, 40, -	Going:  left
# @73, 39, L	Going:  up
# @72, 39, |	Going:  up
# @71, 39, 7	Going:  left
# @71, 38, F	Going:  down
# @72, 38, |	Going:  down
# @73, 38, J	Going:  left
# @73, 37, -	Going:  left
# @73, 36, -	Going:  left
# @73, 35, -	Going:  left
# @73, 34, F	Going:  down
# @74, 34, |	Going:  down
# @75, 34, |	Going:  down
# @76, 34, J	Going:  left
# @76, 33, L	Going:  up
# @75, 33, |	Going:  up
# @74, 33, |	Going:  up
# @73, 33, 7	Going:  left
# @73, 32, F	Going:  down
# @74, 32, |	Going:  down
# @75, 32, |	Going:  down
# @76, 32, |	Going:  down
# @77, 32, J	Going:  left
# @77, 31, L	Going:  up
# @76, 31, |	Going:  up
# @75, 31, |	Going:  up
# @74, 31, 7	Going:  left
# @74, 30, F	Going:  down
# @75, 30, J	Going:  left
# @75, 29, L	Going:  up
# @74, 29, 7	Going:  left
# @74, 28, F	Going:  down
# @75, 28, |	Going:  down
# @76, 28, J	Going:  left
# @76, 27, L	Going:  up
# @75, 27, 7	Going:  left
# @75, 26, F	Going:  down
# @76, 26, J	Going:  left
# @76, 25, L	Going:  up
# @75, 25, |	Going:  up
# @74, 25, F	Going:  right
# @74, 26, -	Going:  right
# @74, 27, J	Going:  up
# @73, 27, |	Going:  up
# @72, 27, 7	Going:  left
# @72, 26, F	Going:  down
# @73, 26, J	Going:  left
# @73, 25, L	Going:  up
# @72, 25, 7	Going:  left
# @72, 24, F	Going:  down
# @73, 24, |	Going:  down
# @74, 24, |	Going:  down
# @75, 24, |	Going:  down
# @76, 24, |	Going:  down
# @77, 24, J	Going:  left
# @77, 23, L	Going:  up
# @76, 23, 7	Going:  left
# @76, 22, F	Going:  down
# @77, 22, J	Going:  left
# @77, 21, L	Going:  up
# @76, 21, 7	Going:  left
# @76, 20, F	Going:  down
# @77, 20, |	Going:  down
# @78, 20, |	Going:  down
# @79, 20, |	Going:  down
# @80, 20, |	Going:  down
# @81, 20, J	Going:  left
# @81, 19, F	Going:  down
# @82, 19, L	Going:  right
# @82, 20, 7	Going:  down
# @83, 20, |	Going:  down
# @84, 20, L	Going:  right
# @84, 21, 7	Going:  down
# @85, 21, |	Going:  down
# @86, 21, J	Going:  left
# @86, 20, L	Going:  up
# @85, 20, 7	Going:  left
# @85, 19, F	Going:  down
# @86, 19, |	Going:  down
# @87, 19, J	Going:  left
# @87, 18, -	Going:  left
# @87, 17, -	Going:  left
# @87, 16, -	Going:  left
# @87, 15, -	Going:  left
# @87, 14, -	Going:  left
# @87, 13, L	Going:  up
# @86, 13, F	Going:  right
# @86, 14, -	Going:  right
# @86, 15, -	Going:  right
# @86, 16, -	Going:  right
# @86, 17, -	Going:  right
# @86, 18, J	Going:  up
# @85, 18, 7	Going:  left
# @85, 17, L	Going:  up
# @84, 17, F	Going:  right
# @84, 18, -	Going:  right
# @84, 19, J	Going:  up
# @83, 19, 7	Going:  left
# @83, 18, -	Going:  left
# @83, 17, L	Going:  up
# @82, 17, F	Going:  right
# @82, 18, J	Going:  up
# @81, 18, 7	Going:  left
# @81, 17, L	Going:  up
# @80, 17, F	Going:  right
# @80, 18, -	Going:  right
# @80, 19, J	Going:  up
# @79, 19, |	Going:  up
# @78, 19, |	Going:  up
# @77, 19, |	Going:  up
# @76, 19, 7	Going:  left
# @76, 18, L	Going:  up
# @75, 18, F	Going:  right
# @75, 19, -	Going:  right
# @75, 20, -	Going:  right
# @75, 21, -	Going:  right
# @75, 22, -	Going:  right
# @75, 23, J	Going:  up
# @74, 23, |	Going:  up
# @73, 23, |	Going:  up
# @72, 23, 7	Going:  left
# @72, 22, F	Going:  down
# @73, 22, |	Going:  down
# @74, 22, J	Going:  left
# @74, 21, L	Going:  up
# @73, 21, |	Going:  up
# @72, 21, 7	Going:  left
# @72, 20, F	Going:  down
# @73, 20, |	Going:  down
# @74, 20, J	Going:  left
# @74, 19, L	Going:  up
# @73, 19, |	Going:  up
# @72, 19, 7	Going:  left
# @72, 18, F	Going:  down
# @73, 18, |	Going:  down
# @74, 18, J	Going:  left
# @74, 17, -	Going:  left
# @74, 16, F	Going:  down
# @75, 16, L	Going:  right
# @75, 17, 7	Going:  down
# @76, 17, |	Going:  down
# @77, 17, L	Going:  right
# @77, 18, 7	Going:  down
# @78, 18, |	Going:  down
# @79, 18, J	Going:  left
# @79, 17, L	Going:  up
# @78, 17, 7	Going:  left
# @78, 16, F	Going:  down
# @79, 16, |	Going:  down
# @80, 16, |	Going:  down
# @81, 16, |	Going:  down
# @82, 16, |	Going:  down
# @83, 16, J	Going:  left
# @83, 15, L	Going:  up
# @82, 15, |	Going:  up
# @81, 15, 7	Going:  left
# @81, 14, F	Going:  down
# @82, 14, |	Going:  down
# @83, 14, |	Going:  down
# @84, 14, L	Going:  right
# @84, 15, -	Going:  right
# @84, 16, 7	Going:  down
# @85, 16, J	Going:  left
# @85, 15, -	Going:  left
# @85, 14, -	Going:  left
# @85, 13, L	Going:  up
# @84, 13, 7	Going:  left
# @84, 12, L	Going:  up
# @83, 12, F	Going:  right
# @83, 13, J	Going:  up
# @82, 13, |	Going:  up
# @81, 13, 7	Going:  left
# @81, 12, -	Going:  left
# @81, 11, F	Going:  down
# @82, 11, |	Going:  down
# @83, 11, |	Going:  down
# @84, 11, |	Going:  down
# @85, 11, L	Going:  right
# @85, 12, 7	Going:  down
# @86, 12, |	Going:  down
# @87, 12, J	Going:  left
# @87, 11, L	Going:  up
# @86, 11, 7	Going:  left
# @86, 10, L	Going:  up
# @85, 10, |	Going:  up
# @84, 10, |	Going:  up
# @83, 10, 7	Going:  left
# @83, 9, F	Going:  down
# @84, 9, |	Going:  down
# @85, 9, J	Going:  left
# @85, 8, F	Going:  down
# @86, 8, J	Going:  left
# @86, 7, L	Going:  up
# @85, 7, 7	Going:  left
# @85, 6, -	Going:  left
# @85, 5, L	Going:  up
# @84, 5, F	Going:  right
# @84, 6, -	Going:  right
# @84, 7, -	Going:  right
# @84, 8, J	Going:  up
# @83, 8, |	Going:  up
# @82, 8, F	Going:  right
# @82, 9, -	Going:  right
# @82, 10, J	Going:  up
# @81, 10, 7	Going:  left
# @81, 9, -	Going:  left
# @81, 8, -	Going:  left
# @81, 7, L	Going:  up
# @80, 7, F	Going:  right
# @80, 8, -	Going:  right
# @80, 9, J	Going:  up
# @79, 9, F	Going:  right
# @79, 10, 7	Going:  down
# @80, 10, L	Going:  right
# @80, 11, -	Going:  right
# @80, 12, -	Going:  right
# @80, 13, -	Going:  right
# @80, 14, -	Going:  right
# @80, 15, J	Going:  up
# @79, 15, 7	Going:  left
# @79, 14, -	Going:  left
# @79, 13, -	Going:  left
# @79, 12, L	Going:  up
# @78, 12, F	Going:  right
# @78, 13, -	Going:  right
# @78, 14, -	Going:  right
# @78, 15, J	Going:  up
# @77, 15, F	Going:  right
# @77, 16, J	Going:  up
# @76, 16, 7	Going:  left
# @76, 15, -	Going:  left
# @76, 14, F	Going:  down
# @77, 14, J	Going:  left
# @77, 13, L	Going:  up
# @76, 13, 7	Going:  left
# @76, 12, L	Going:  up
# @75, 12, F	Going:  right
# @75, 13, -	Going:  right
# @75, 14, -	Going:  right
# @75, 15, J	Going:  up
# @74, 15, 7	Going:  left
# @74, 14, L	Going:  up
# @73, 14, F	Going:  right
# @73, 15, -	Going:  right
# @73, 16, -	Going:  right
# @73, 17, J	Going:  up
# @72, 17, 7	Going:  left
# @72, 16, -	Going:  left
# @72, 15, -	Going:  left
# @72, 14, -	Going:  left
# @72, 13, F	Going:  down
# @73, 13, |	Going:  down
# @74, 13, J	Going:  left
# @74, 12, L	Going:  up
# @73, 12, 7	Going:  left
# @73, 11, F	Going:  down
# @74, 11, |	Going:  down
# @75, 11, |	Going:  down
# @76, 11, |	Going:  down
# @77, 11, |	Going:  down
# @78, 11, J	Going:  left
# @78, 10, -	Going:  left
# @78, 9, L	Going:  up
# @77, 9, F	Going:  right
# @77, 10, J	Going:  up
# @76, 10, |	Going:  up
# @75, 10, |	Going:  up
# @74, 10, 7	Going:  left
# @74, 9, F	Going:  down
# @75, 9, |	Going:  down
# @76, 9, J	Going:  left
# @76, 8, F	Going:  down
# @77, 8, J	Going:  left
# @77, 7, L	Going:  up
# @76, 7, 7	Going:  left
# @76, 6, L	Going:  up
# @75, 6, F	Going:  right
# @75, 7, -	Going:  right
# @75, 8, J	Going:  up
# @74, 8, |	Going:  up
# @73, 8, 7	Going:  left
# @73, 7, F	Going:  down
# @74, 7, J	Going:  left
# @74, 6, L	Going:  up
# @73, 6, 7	Going:  left
# @73, 5, L	Going:  up
# @72, 5, F	Going:  right
# @72, 6, -	Going:  right
# @72, 7, -	Going:  right
# @72, 8, J	Going:  up
# @71, 8, F	Going:  right
# @71, 9, 7	Going:  down
# @72, 9, |	Going:  down
# @73, 9, L	Going:  right
# @73, 10, J	Going:  up
# @72, 10, |	Going:  up
# @71, 10, F	Going:  right
# @71, 11, 7	Going:  down
# @72, 11, L	Going:  right
# @72, 12, J	Going:  up
# @71, 12, |	Going:  up
# @70, 12, 7	Going:  left
# @70, 11, -	Going:  left
# @70, 10, -	Going:  left
# @70, 9, -	Going:  left
# @70, 8, -	Going:  left
# @70, 7, F	Going:  down
# @71, 7, J	Going:  left
# @71, 6, L	Going:  up
# @70, 6, 7	Going:  left
# @70, 5, L	Going:  up
# @69, 5, 7	Going:  left
# @69, 4, F	Going:  down
# @70, 4, J	Going:  left
# @70, 3, L	Going:  up
# @69, 3, 7	Going:  left
# @69, 2, F	Going:  down
# @70, 2, |	Going:  down
# @71, 2, J	Going:  left
# @71, 1, L	Going:  up
# @70, 1, |	Going:  up
# @69, 1, 7	Going:  left
# @69, 0, L	Going:  up
# @68, 0, F	Going:  right
# @68, 1, -	Going:  right
# @68, 2, -	Going:  right
# @68, 3, J	Going:  up
# @67, 3, 7	Going:  left
# @67, 2, -	Going:  left
# @67, 1, -	Going:  left
# @67, 0, L	Going:  up
# @66, 0, F	Going:  right
# @66, 1, -	Going:  right
# @66, 2, -	Going:  right
# @66, 3, J	Going:  up
# @65, 3, |	Going:  up
# @64, 3, F	Going:  right
# @64, 4, 7	Going:  down
# @65, 4, |	Going:  down
# @66, 4, |	Going:  down
# @67, 4, |	Going:  down
# @68, 4, L	Going:  right
# @68, 5, J	Going:  up
# @67, 5, |	Going:  up
# @66, 5, F	Going:  right
# @66, 6, 7	Going:  down
# @67, 6, |	Going:  down
# @68, 6, |	Going:  down
# @69, 6, L	Going:  right
# @69, 7, J	Going:  up
# @68, 7, |	Going:  up
# @67, 7, F	Going:  right
# @67, 8, 7	Going:  down
# @68, 8, |	Going:  down
# @69, 8, L	Going:  right
# @69, 9, -	Going:  right
# @69, 10, -	Going:  right
# @69, 11, J	Going:  up
# @68, 11, 7	Going:  left
# @68, 10, -	Going:  left
# @68, 9, L	Going:  up
# @67, 9, F	Going:  right
# @67, 10, J	Going:  up
# @66, 10, |	Going:  up
# @65, 10, F	Going:  right
# @65, 11, 7	Going:  down
# @66, 11, |	Going:  down
# @67, 11, L	Going:  right
# @67, 12, 7	Going:  down
# @68, 12, |	Going:  down
# @69, 12, L	Going:  right
# @69, 13, 7	Going:  down
# @70, 13, |	Going:  down
# @71, 13, L	Going:  right
# @71, 14, J	Going:  up
# @70, 14, |	Going:  up
# @69, 14, F	Going:  right
# @69, 15, 7	Going:  down
# @70, 15, |	Going:  down
# @71, 15, L	Going:  right
# @71, 16, -	Going:  right
# @71, 17, -	Going:  right
# @71, 18, J	Going:  up
# @70, 18, 7	Going:  left
# @70, 17, -	Going:  left
# @70, 16, L	Going:  up
# @69, 16, |	Going:  up
# @68, 16, 7	Going:  left
# @68, 15, L	Going:  up
# @67, 15, 7	Going:  left
# @67, 14, F	Going:  down
# @68, 14, J	Going:  left
# @68, 13, L	Going:  up
# @67, 13, |	Going:  up
# @66, 13, 7	Going:  left
# @66, 12, L	Going:  up
# @65, 12, F	Going:  right
# @65, 13, -	Going:  right
# @65, 14, 7	Going:  down
# @66, 14, L	Going:  right
# ...
# 244 241
# Cur: 254:185
# 253 185
# 254 184
# 254 186
# 255 185
# Cur: 253:83
# 252 83
# 253 82
# 253 84
# 254 83
# Cur: 250:189
# 249 189
# 250 188
# 250 190
# 251 189
# Cur: 23:225
# 22 225
# 23 224
# 23 226
# 24 225
# Cur: 256:89
# 255 89
# 256 88
# 256 90
# 257 89
# Cur: 223:24
# 222 24
# 223 23
# 223 25
# 224 24
# Cur: 39:249
# 38 249
# 39 248
# 39 250
# 40 249
# Cur: 207:23
# 206 23
# 207 22
# 207 24
# 208 23
# Cur: 37:237
# 36 237
# 37 236
# 37 238
# 38 237
# Cur: 270:125
# 269 125
# 270 124
# 270 126
# 271 125
# Cur: 268:125
# 267 125
# 268 124
# 268 126
# 269 125
# Cur: 22:233
# 21 233
# 22 232
# 22 234
# 23 233
# Cur: 211:15
# 210 15
# 211 14
# 211 16
# 212 15
# Cur: 250:59
# 249 59
# 250 58
# 250 60
# 251 59
# Cur: 27:237
# 26 237
# 27 236
# 27 238
# 28 237
# Cur: 254:95
# 253 95
# 254 94
# 254 96
# 255 95
# Cur: 55:255
# 54 255
# 55 254
# 55 256
# 56 255
# Cur: 45:253
# 44 253
# 45 252
# 45 254
# 46 253
# Cur: 247:67
# 246 67
# 247 66
# 247 68
# 248 67
# Cur: 245:239
# 244 239
# 245 238
# 245 240
# 246 239
# Cur: 251:81
# 250 81
# 251 80
# 251 82
# 252 81
# Cur: 238:45
# 237 45
# 238 44
# 238 46
# 239 45
# Cur: 29:241
# 28 241
# 29 240
# 29 242
# 30 241
# Cur: 204:19
# 203 19
# 204 18
# 204 20
# 205 19
# Cur: 273:120
# 272 120
# 273 119
# 273 121
# 274 120
# Cur: 241:45
# 240 45
# 241 44
# 241 46
# 242 45
# Cur: 49:251
# 48 251
# 49 250
# 49 252
# 50 251
# Cur: 223:21
# 222 21
# 223 20
# 223 22
# 224 21
# Cur: 249:190
# 248 190
# 249 189
# 249 191
# 250 190
# Cur: 243:242
# 242 242
# 243 241
# 243 243
# 244 242
# Cur: 247:80
# 246 80
# 247 79
# 247 81
# 248 80
# Cur: 271:125
